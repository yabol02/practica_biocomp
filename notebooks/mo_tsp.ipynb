    (0.1263309724872509, 0.9185321014517236),
    (0.24969404380600335, 0.9600467657522086),
    (0.5886119367943214, 0.10948123668473264),
    (0.13373527735293878, 0.5336853876899833),
    (0.5642696742735989, 0.9801384844337597),
    (0.646401605512568, 0.3338636388089157),
    (0.05603526365085032, 0.3149530712641142),
    (0.387141492676661, 0.5792852545912592),
    (0.8634070619751958, 0.8206820685065667),
    (0.4662474858565825, 0.32647667516764145),
    (0.01801973379815025, 0.12175434785651695),
    (0.6218125565554127, 0.07860046445444713),
    (0.6573938922925594, 0.5023092428939168),
    (0.2837581848186974, 0.02576704782244421),
    (0.3044774374252185, 0.7310313422019327),
    (0.33131673439274434, 0.693896434962478),
    (0.8523694048117944, 0.2805224723356823),
    (0.6200019812032047, 0.03989814578273998),
    (0.5437394088109648, 0.3258031129949792),
    (0.4386079860370994, 0.6142798815693052),
    (0.7430581106897977, 0.49260737229959284),
    (0.3913628378102181, 0.3185830750836698),
    (0.9065498976196814, 0.02381958527497441),
    (0.6874236611131453, 0.18642068590773597),
    (0.6946411585627993, 0.36991609629423117),
    (0.3784063098306413, 0.01018756575849844),
    (0.43806374889930155, 0.2268325586117821),
    (0.7411632641820634, 0.35513151640087337),
    (0.3884706603234591, 0.34043302784114093),
    (0.08674110453583683, 0.4491174987265194),
    (0.9794883193315694, 0.11207520940235804),
    (0.7496156619797683, 0.23845386610980834),
    (0.4423888847621813, 0.17212722421686055),
    (0.2276570035864689, 0.6515924491551327),
    (0.836939257954547, 0.0499933914625984),
)

# %%
import random

import matplotlib.pyplot as plt
import numpy as np

from genetic.algorithms import GeneticAlgorithmMO
from genetic.configurations import ProblemConfig
from genetic.crossover import OrderCrossover
from genetic.initialization import PermutationInitialization
from genetic.mutation import SwapMutation
from genetic.problems import MOTSProblem
from genetic.replacement import GenerationalReplacement
from genetic.selection import ParetoSelection

# %%
plt.style.use("dark_background")
random.seed(42)
np.random.seed(42)


def create_figure(w=12, h=8):
    fig = plt.figure(figsize=(w, h))
    ax = fig.add_subplot(111, projection="3d")
    return fig, ax


def plot_nodes(ax, nodes, elevations, color="r", size=5):
    x_coords, y_coords = zip(*nodes)
    ax.scatter(x_coords, y_coords, elevations, c=color, s=size)


def plot_path(ax, path, elevations, color="b", linewidth=1.5):
    x_path, y_path = zip(*path)
    ax.plot(x_path, y_path, elevations, color=color, linewidth=linewidth)

# %%
config = ProblemConfig(max_evaluations=100000, seed=42, output_dir="results/tsp")

# Problem
problem = MOTSProblem(config, cities, perlin_seed=42)

# Operators
initialization = PermutationInitialization()
selection = ParetoSelection()
crossover = OrderCrossover()
mutation = SwapMutation(mutation_rate=0.15)
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

x_coords, y_coords = zip(*cities)
z_coords = problem.elevations

x = np.array(x_coords)
y = np.array(y_coords)
z = np.array(z_coords)

xi = np.linspace(x.min(), x.max(), 200)
yi = np.linspace(y.min(), y.max(), 200)
xi, yi = np.meshgrid(xi, yi)

zi = griddata((x, y), z, (xi, yi), method="cubic")

fig, axes = plt.subplots(1, 2, figsize=(20, 7))

ax1 = fig.add_subplot(121, projection="3d")
scatter = ax1.scatter(x, y, z, c=z, cmap="terrain", s=50)
ax1.set_xlabel("Coordenada X")
ax1.set_ylabel("Coordenada Y")
ax1.set_zlabel("Elevación")
ax1.set_title("Representación 3D de Ciudades")

ax2 = axes[1]
img = ax2.imshow(
    zi,
    extent=(x.min(), x.max(), y.min(), y.max()),
    origin="lower",
    cmap="terrain",
    aspect="auto"
)
ax2.set_title("Mapa de alturas")
ax2.set_xlabel("Coordenada X")
ax2.set_ylabel("Coordenada Y")
plt.colorbar(img, ax=ax2, label="Altura")

plt.show()

# %%
from matplotlib.pyplot import imshow
from matplotlib.pyplot import subplots

fig, axes = subplots(1, 2)
axes[0].imshow(problem.dist_matrix)
axes[1].imshow(problem.time_matrix)

# %%
# Al final del todo calcula el frente de Pareto final y suele tardar bastante tiempo (16'5 min aprox)
result = ga.run()
# Out:
# Gen 0: Evals=50/100000, Pareto size=1, Sample objectives=['53.6007', '2543.7495']
# Gen 10: Evals=550/100000, Pareto size=13, Sample objectives=['49.7053', '2316.9013']
# Gen 20: Evals=1050/100000, Pareto size=5, Sample objectives=['48.0088', '2104.1218']
# Gen 30: Evals=1550/100000, Pareto size=3, Sample objectives=['45.2619', '2015.5805']
# Gen 40: Evals=2050/100000, Pareto size=3, Sample objectives=['45.2539', '2015.5725']
# Gen 50: Evals=2550/100000, Pareto size=6, Sample objectives=['45.3962', '1956.9827']
# Gen 60: Evals=3050/100000, Pareto size=4, Sample objectives=['45.0431', '1949.0601']
# Gen 70: Evals=3550/100000, Pareto size=5, Sample objectives=['48.2992', '2190.3109']
# Gen 80: Evals=4050/100000, Pareto size=19, Sample objectives=['45.0698', '1927.6250']
# Gen 90: Evals=4550/100000, Pareto size=4, Sample objectives=['45.2941', '1990.5856']
# Gen 100: Evals=5050/100000, Pareto size=5, Sample objectives=['44.4800', '1989.7333']
# Gen 110: Evals=5550/100000, Pareto size=6, Sample objectives=['42.6656', '1893.8965']
# Gen 120: Evals=6050/100000, Pareto size=5, Sample objectives=['41.6973', '1825.5861']
# Gen 130: Evals=6550/100000, Pareto size=5, Sample objectives=['41.6973', '1825.5861']
# Gen 140: Evals=7050/100000, Pareto size=1, Sample objectives=['41.7834', '1812.3758']
# Gen 150: Evals=7550/100000, Pareto size=10, Sample objectives=['41.5395', '1835.4780']
# Gen 160: Evals=8050/100000, Pareto size=2, Sample objectives=['42.3983', '1817.6412']
# Gen 170: Evals=8550/100000, Pareto size=2, Sample objectives=['41.4427', '1774.3500']
# Gen 180: Evals=9050/100000, Pareto size=2, Sample objectives=['40.3572', '1766.4842']
# Gen 190: Evals=9550/100000, Pareto size=16, Sample objectives=['40.3198', '1689.6294']
# Gen 200: Evals=10050/100000, Pareto size=9, Sample objectives=['43.4588', '1949.1455']
# Gen 210: Evals=10550/100000, Pareto size=9, Sample objectives=['40.7014', '1796.9179']
# Gen 220: Evals=11050/100000, Pareto size=9, Sample objectives=['39.4729', '1742.3202']
# Gen 230: Evals=11550/100000, Pareto size=10, Sample objectives=['40.3730', '1752.7919']
# Gen 240: Evals=12050/100000, Pareto size=11, Sample objectives=['40.1935', '1715.7254']
# Gen 250: Evals=12550/100000, Pareto size=9, Sample objectives=['44.1361', '1992.2171']
# Gen 260: Evals=13050/100000, Pareto size=14, Sample objectives=['47.6190', '2195.6860']
# Gen 270: Evals=13550/100000, Pareto size=14, Sample objectives=['40.1484', '1704.8725']
# Gen 280: Evals=14050/100000, Pareto size=3, Sample objectives=['40.4451', '1669.2287']
# Gen 290: Evals=14550/100000, Pareto size=3, Sample objectives=['39.7943', '1669.7048']
# Gen 300: Evals=15050/100000, Pareto size=2, Sample objectives=['39.3691', '1659.3293']
# Gen 310: Evals=15550/100000, Pareto size=3, Sample objectives=['42.6424', '1864.7271']
# Gen 320: Evals=16050/100000, Pareto size=5, Sample objectives=['41.4915', '1726.9735']
# Gen 330: Evals=16550/100000, Pareto size=2, Sample objectives=['38.4919', '1631.5619']
# Gen 340: Evals=17050/100000, Pareto size=2, Sample objectives=['39.1502', '1630.7786']
# Gen 350: Evals=17550/100000, Pareto size=2, Sample objectives=['39.0238', '1625.7588']
# Gen 360: Evals=18050/100000, Pareto size=2, Sample objectives=['42.0515', '1816.8288']
# Gen 370: Evals=18550/100000, Pareto size=2, Sample objectives=['38.0297', '1573.5240']
# Gen 380: Evals=19050/100000, Pareto size=3, Sample objectives=['38.0297', '1573.5240']
# Gen 390: Evals=19550/100000, Pareto size=6, Sample objectives=['38.4968', '1557.3214']
# Gen 400: Evals=20050/100000, Pareto size=17, Sample objectives=['45.0928', '2030.8481']
# Gen 410: Evals=20550/100000, Pareto size=4, Sample objectives=['37.4029', '1522.2193']
# Gen 420: Evals=21050/100000, Pareto size=5, Sample objectives=['41.0423', '1813.2319']
# Gen 430: Evals=21550/100000, Pareto size=7, Sample objectives=['37.4029', '1522.2193']
# Gen 440: Evals=22050/100000, Pareto size=10, Sample objectives=['37.4711', '1513.7499']
# Gen 450: Evals=22550/100000, Pareto size=10, Sample objectives=['37.4711', '1513.7499']
# Gen 460: Evals=23050/100000, Pareto size=10, Sample objectives=['40.6644', '1728.4693']
# Gen 470: Evals=23550/100000, Pareto size=4, Sample objectives=['36.9331', '1510.1782']
# Gen 480: Evals=24050/100000, Pareto size=6, Sample objectives=['37.4614', '1545.0264']
# Gen 490: Evals=24550/100000, Pareto size=6, Sample objectives=['43.0950', '1888.7444']
# Gen 500: Evals=25050/100000, Pareto size=6, Sample objectives=['36.7423', '1509.9874']
# Gen 510: Evals=25550/100000, Pareto size=3, Sample objectives=['36.2264', '1454.3030']
# Gen 520: Evals=26050/100000, Pareto size=4, Sample objectives=['37.7533', '1598.5060']
# Gen 530: Evals=26550/100000, Pareto size=4, Sample objectives=['49.3130', '2335.4361']
# Gen 540: Evals=27050/100000, Pareto size=6, Sample objectives=['37.1447', '1526.7823']
# Gen 550: Evals=27550/100000, Pareto size=5, Sample objectives=['36.0731', '1507.3460']
# Gen 560: Evals=28050/100000, Pareto size=6, Sample objectives=['36.0731', '1507.3460']
# Gen 570: Evals=28550/100000, Pareto size=8, Sample objectives=['39.1469', '1657.9091']
# Gen 580: Evals=29050/100000, Pareto size=10, Sample objectives=['46.4205', '2167.7164']
# Gen 590: Evals=29550/100000, Pareto size=6, Sample objectives=['42.1998', '1886.5396']
# Gen 600: Evals=30050/100000, Pareto size=5, Sample objectives=['35.6534', '1531.1330']
# Gen 610: Evals=30550/100000, Pareto size=5, Sample objectives=['37.3690', '1569.8767']
# Gen 620: Evals=31050/100000, Pareto size=4, Sample objectives=['35.4799', '1476.2904']
# Gen 630: Evals=31550/100000, Pareto size=4, Sample objectives=['47.5905', '2195.6574']
# Gen 640: Evals=32050/100000, Pareto size=4, Sample objectives=['35.4710', '1491.9172']
# Gen 650: Evals=32550/100000, Pareto size=4, Sample objectives=['35.8998', '1506.7287']
# Gen 660: Evals=33050/100000, Pareto size=1, Sample objectives=['35.4710', '1491.9172']
# Gen 670: Evals=33550/100000, Pareto size=5, Sample objectives=['34.5641', '1456.5231']
# Gen 680: Evals=34050/100000, Pareto size=1, Sample objectives=['33.7288', '1389.9663']
# Gen 690: Evals=34550/100000, Pareto size=1, Sample objectives=['35.2089', '1438.6531']
# Gen 700: Evals=35050/100000, Pareto size=1, Sample objectives=['46.2885', '2113.0196']
# Gen 710: Evals=35550/100000, Pareto size=1, Sample objectives=['35.1792', '1472.5860']
# Gen 720: Evals=36050/100000, Pareto size=1, Sample objectives=['46.9255', '2159.1455']
# Gen 730: Evals=36550/100000, Pareto size=1, Sample objectives=['39.3342', '1619.9495']
# Gen 740: Evals=37050/100000, Pareto size=1, Sample objectives=['35.4071', '1418.4825']
# Gen 750: Evals=37550/100000, Pareto size=1, Sample objectives=['34.2221', '1397.6359']
# Gen 760: Evals=38050/100000, Pareto size=1, Sample objectives=['35.7224', '1394.2796']
# Gen 770: Evals=38550/100000, Pareto size=1, Sample objectives=['34.1914', '1389.5431']
# Gen 780: Evals=39050/100000, Pareto size=1, Sample objectives=['42.1897', '1832.7581']
# Gen 790: Evals=39550/100000, Pareto size=1, Sample objectives=['38.7903', '1591.1899']
# Gen 800: Evals=40050/100000, Pareto size=1, Sample objectives=['49.4073', '2272.5309']
# Gen 810: Evals=40550/100000, Pareto size=2, Sample objectives=['35.0449', '1374.4175']
# Gen 820: Evals=41050/100000, Pareto size=3, Sample objectives=['42.1446', '1851.2105']
# Gen 830: Evals=41550/100000, Pareto size=3, Sample objectives=['34.1914', '1389.5431']
# Gen 840: Evals=42050/100000, Pareto size=3, Sample objectives=['35.3985', '1445.7775']
# Gen 850: Evals=42550/100000, Pareto size=3, Sample objectives=['34.1914', '1389.5431']
# Gen 860: Evals=43050/100000, Pareto size=3, Sample objectives=['34.1914', '1389.5431']
# Gen 870: Evals=43550/100000, Pareto size=3, Sample objectives=['34.5025', '1346.5566']
# Gen 880: Evals=44050/100000, Pareto size=4, Sample objectives=['37.5963', '1498.1910']
# Gen 890: Evals=44550/100000, Pareto size=4, Sample objectives=['34.1914', '1389.5431']
# Gen 900: Evals=45050/100000, Pareto size=4, Sample objectives=['42.1446', '1851.2105']
# Gen 910: Evals=45550/100000, Pareto size=4, Sample objectives=['35.2883', '1452.5940']
# Gen 920: Evals=46050/100000, Pareto size=4, Sample objectives=['43.0183', '1919.9676']
# Gen 930: Evals=46550/100000, Pareto size=4, Sample objectives=['47.0928', '2129.2156']
# Gen 940: Evals=47050/100000, Pareto size=4, Sample objectives=['35.6888', '1441.8801']
# Gen 950: Evals=47550/100000, Pareto size=4, Sample objectives=['42.0869', '1827.4405']
# Gen 960: Evals=48050/100000, Pareto size=4, Sample objectives=['34.1914', '1389.5431']
# Gen 970: Evals=48550/100000, Pareto size=4, Sample objectives=['34.1914', '1389.5431']
# Gen 980: Evals=49050/100000, Pareto size=4, Sample objectives=['34.1914', '1389.5431']
# Gen 990: Evals=49550/100000, Pareto size=7, Sample objectives=['34.4324', '1449.8721']
# Gen 1000: Evals=50050/100000, Pareto size=7, Sample objectives=['33.5249', '1390.7933']
# Gen 1010: Evals=50550/100000, Pareto size=7, Sample objectives=['48.9117', '2277.8479']
# Gen 1020: Evals=51050/100000, Pareto size=7, Sample objectives=['33.4671', '1389.2718']
# Gen 1030: Evals=51550/100000, Pareto size=8, Sample objectives=['33.9269', '1380.1181']
# Gen 1040: Evals=52050/100000, Pareto size=9, Sample objectives=['39.6154', '1684.2724']
# Gen 1050: Evals=52550/100000, Pareto size=9, Sample objectives=['36.7753', '1570.4448']
# Gen 1060: Evals=53050/100000, Pareto size=9, Sample objectives=['35.9159', '1468.9701']
# Gen 1070: Evals=53550/100000, Pareto size=9, Sample objectives=['48.6719', '2208.5007']
# Gen 1080: Evals=54050/100000, Pareto size=9, Sample objectives=['34.8011', '1322.9667']
# Gen 1090: Evals=54550/100000, Pareto size=10, Sample objectives=['34.1656', '1322.3312']
# Gen 1100: Evals=55050/100000, Pareto size=10, Sample objectives=['34.4824', '1321.4814']
# Gen 1110: Evals=55550/100000, Pareto size=10, Sample objectives=['34.3734', '1322.5390']
# Gen 1120: Evals=56050/100000, Pareto size=10, Sample objectives=['34.1656', '1322.3312']
# Gen 1130: Evals=56550/100000, Pareto size=19, Sample objectives=['47.8462', '2146.4576']
# Gen 1140: Evals=57050/100000, Pareto size=19, Sample objectives=['49.2003', '2272.7768']
# Gen 1150: Evals=57550/100000, Pareto size=19, Sample objectives=['34.1824', '1307.2462']
# Gen 1480: Evals=74050/100000, Pareto size=33, Sample objectives=['49.6539', '2301.6415']
# Gen 1490: Evals=74550/100000, Pareto size=33, Sample objectives=['35.1956', '1274.4145']
# Gen 1500: Evals=75050/100000, Pareto size=9, Sample objectives=['48.8095', '2197.5160']
# Gen 1510: Evals=75550/100000, Pareto size=9, Sample objectives=['34.6045', '1253.1086']
# Gen 1520: Evals=76050/100000, Pareto size=9, Sample objectives=['43.7678', '1936.9750']
# Gen 1530: Evals=76550/100000, Pareto size=9, Sample objectives=['34.6045', '1253.1086']
# Gen 1540: Evals=77050/100000, Pareto size=10, Sample objectives=['35.8629', '1291.1494']
# Gen 1550: Evals=77550/100000, Pareto size=14, Sample objectives=['35.2776', '1213.3582']
# Gen 1560: Evals=78050/100000, Pareto size=10, Sample objectives=['48.9858', '2241.1609']
# Gen 1570: Evals=78550/100000, Pareto size=8, Sample objectives=['34.4078', '1182.8084']
# Gen 1580: Evals=79050/100000, Pareto size=8, Sample objectives=['34.4078', '1182.8084']
# Gen 1590: Evals=79550/100000, Pareto size=7, Sample objectives=['39.9695', '1620.3467']
# Gen 1600: Evals=80050/100000, Pareto size=7, Sample objectives=['35.0583', '1260.2029']
# Gen 1610: Evals=80550/100000, Pareto size=11, Sample objectives=['33.4071', '1153.2421']
# Gen 1620: Evals=81050/100000, Pareto size=5, Sample objectives=['34.0028', '1174.5016']
# Gen 1630: Evals=81550/100000, Pareto size=5, Sample objectives=['33.9047', '1182.4565']
# Gen 1640: Evals=82050/100000, Pareto size=5, Sample objectives=['36.3886', '1410.6105']
# Gen 1650: Evals=82550/100000, Pareto size=5, Sample objectives=['33.2181', '1161.8063']
# Gen 1660: Evals=83050/100000, Pareto size=4, Sample objectives=['33.4474', '1191.7763']
# Gen 1670: Evals=83550/100000, Pareto size=2, Sample objectives=['33.4474', '1191.7763']
# Gen 1680: Evals=84050/100000, Pareto size=2, Sample objectives=['41.6960', '1790.8931']
# Gen 1690: Evals=84550/100000, Pareto size=2, Sample objectives=['33.2912', '1163.2039']
# Gen 1700: Evals=85050/100000, Pareto size=2, Sample objectives=['36.7879', '1432.7337']
# Gen 1710: Evals=85550/100000, Pareto size=2, Sample objectives=['33.2912', '1163.2039']
# Gen 1720: Evals=86050/100000, Pareto size=2, Sample objectives=['46.4145', '2051.4174']
# Gen 1730: Evals=86550/100000, Pareto size=2, Sample objectives=['35.0757', '1332.1176']
# Gen 1740: Evals=87050/100000, Pareto size=2, Sample objectives=['37.6734', '1480.6619']
# Gen 1750: Evals=87550/100000, Pareto size=2, Sample objectives=['33.0323', '1143.9276']
# Gen 1760: Evals=88050/100000, Pareto size=2, Sample objectives=['48.9862', '2151.5833']
# Gen 1770: Evals=88550/100000, Pareto size=2, Sample objectives=['33.2025', '1167.6587']
# Gen 1780: Evals=89050/100000, Pareto size=2, Sample objectives=['33.2025', '1167.6587']
# Gen 1790: Evals=89550/100000, Pareto size=2, Sample objectives=['35.4316', '1383.8246']
# Gen 1800: Evals=90050/100000, Pareto size=5, Sample objectives=['49.3292', '2281.0378']
# Gen 1810: Evals=90550/100000, Pareto size=5, Sample objectives=['39.1668', '1622.8761']
# Gen 1820: Evals=91050/100000, Pareto size=5, Sample objectives=['33.0407', '1167.6370']
# Gen 1830: Evals=91550/100000, Pareto size=5, Sample objectives=['45.5938', '1944.7659']
# Gen 1840: Evals=92050/100000, Pareto size=31, Sample objectives=['32.9509', '1162.6555']
# Gen 1850: Evals=92550/100000, Pareto size=31, Sample objectives=['34.2946', '1240.5813']
# Gen 1860: Evals=93050/100000, Pareto size=31, Sample objectives=['33.0407', '1167.6370']
# Gen 1870: Evals=93550/100000, Pareto size=31, Sample objectives=['47.4967', '2087.8457']
# Gen 1880: Evals=94050/100000, Pareto size=2, Sample objectives=['33.0407', '1167.6370']
# Gen 1890: Evals=94550/100000, Pareto size=2, Sample objectives=['32.5321', '1145.8106']
# Gen 1900: Evals=95050/100000, Pareto size=3, Sample objectives=['39.6637', '1575.9713']
# Gen 1910: Evals=95550/100000, Pareto size=3, Sample objectives=['47.2575', '2110.1379']
# Gen 1920: Evals=96050/100000, Pareto size=3, Sample objectives=['46.8031', '2089.3937']
# Gen 1930: Evals=96550/100000, Pareto size=3, Sample objectives=['33.8464', '1196.3512']
# Gen 1940: Evals=97050/100000, Pareto size=3, Sample objectives=['49.1376', '2316.9801']
# Gen 1950: Evals=97550/100000, Pareto size=3, Sample objectives=['33.7149', '1172.8109']
# Gen 1960: Evals=98050/100000, Pareto size=3, Sample objectives=['33.7149', '1172.8109']
# Gen 1970: Evals=98550/100000, Pareto size=3, Sample objectives=['48.0982', '2133.4677']
# Gen 1980: Evals=99050/100000, Pareto size=3, Sample objectives=['37.0055', '1371.6790']
# Gen 1990: Evals=99550/100000, Pareto size=3, Sample objectives=['44.9672', '1971.1477']

# %%
print("\n" + "=" * 40)
print("RESULTS")
print("=" * 40)
print(f"Problem: {result.problem_name}")
print(f"Best distances-time:")
for pareto in result.pareto_front:
    dist, time = pareto
    print(f"  - Distance: {dist:.8f}, Time: {time:.8f}")
print(f"Evaluations used: {result.evaluations_used}")
print(f"Generations: {len(result.history)}")
print(f"Metrics:")
for metric, value in result.metrics.items():
    print(f"  - {metric}: {value}")
# Out:
# ========================================
# RESULTS
# ========================================
# Problem: MOTSProblem
# Best distances-time:
#   - Distance: 32.44509267, Time: 1095.90649651
#   - Distance: 32.20477243, Time: 1121.09322626
#   - Distance: 32.00197137, Time: 1163.49104263
# Evaluations used: 100000
# Generations: 0
# Metrics:
#   - n_pareto_solutions: 3
#   - pareto_spread: 388.8840168180945
#   - history_length: 2001

# %%
front = problem.plot_pareto_front()
front.show()

# %%
cities_solution = [cities[idx] for idx in result.best_solution[0]]
cities_solution.append(cities_solution[0])
elevations = problem.elevations.tolist()
elevations.append(elevations[0])

fig, ax = create_figure()
plot_nodes(ax, cities_solution, elevations)
plot_path(ax, cities_solution, elevations)
