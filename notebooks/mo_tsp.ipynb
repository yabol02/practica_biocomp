# %%
cd ..
# Out:
# c:\Users\Yago\Desktop\MAADM\3 Computación Evolutiva y Bioinspirada\practica_biocomp

# %%
# %load_ext autoreload
# %autoreload 2

# %%
cities = (
    (0.8744058793117488, 0.30207179832703746),
    (0.6901572276474558, 0.8203362566663311),
    (0.7793458478083026, 0.09728979746351918),
    (0.7483358474304422, 0.4563419482458657),
    (0.4556164527790729, 0.12863149772605698),
    (0.1837236688553453, 0.23773749495644914),
    (0.806151832654163, 0.3288366900529254),
    (0.6222702185205219, 0.6019431085670109),
    (0.21886861543988367, 0.6980104036528004),
    (0.9706096813038716, 0.054871876245520146),
    (0.13881496219356027, 0.048489530185603646),
    (0.08511086492841424, 0.9123075505436051),
    (0.45436952164297595, 0.4731540740573398),
    (0.8986352255038935, 0.5116579750591849),
    (0.9539248970461742, 0.7530784036308166),
    (0.6321102985156373, 0.13575967095580344),
    (0.31130918313591205, 0.8545457319320597),
    (0.025897479791937017, 0.7854526665590987),
    (0.31414095045738066, 0.051421702103483846),
    (0.2739561013272712, 0.1970964027924862),
    (0.22762328443470214, 0.627414210742153),
    (0.44920042912037383, 0.18835427573438068),
    (0.2793138301174244, 0.9103956650199608),
    (0.005128451667189338, 0.4655718085045638),
    (0.9222718335261915, 0.8613103704784812),
    (0.49352498279326595, 0.28652416807644077),
    (0.5560886356057152, 0.034564925228364185),
    (0.0048939219846825255, 0.8635350555457212),
    (0.7824462381771976, 0.09355415747424733),
    (0.2973635133076785, 0.037580527218207815),
    (0.659068210692151, 0.5602321147981546),
    (0.43549418718677035, 0.6241289474799954),
    (0.25580657871099755, 0.519726015381631),
    (0.5950780852425872, 0.3193476592023645),
    (0.15763623266223903, 0.18210618406479095),
    (0.3434173147566393, 0.32992255868483356),
    (0.06451313705472006, 0.12606114349173192),
    (0.23212286400737547, 0.3945559700824013),
    (0.955507285594692, 0.02296933408938162),
    (0.7459955912073274, 0.1385374827130177),
    (0.46365765315595475, 0.6132297411379687),
    (0.20196772698059162, 0.046358747430397584),
    (0.2980093518214506, 0.36041197123227897),
    (0.7533459401199348, 0.6610562232191091),
    (0.323433933838161, 0.5068337090138902),
    (0.062138830138457, 0.7177455044259695),
    (0.47467832142010535, 0.17692718986260936),
    (0.2415634321550142, 0.500852093941769),
    (0.3441878827094532, 0.2604351258948506),
    (0.5445252142594251, 0.7295590645635646),
    (0.25391391610860914, 0.7641244059389684),
    (0.2630560480211699, 0.010670642241309536),
    (0.2092202940037915, 0.7415775443241935),
    (0.0031474687633804566, 0.6974574785842637),
    (0.4952329615559806, 0.9311775894780175),
    (0.1978488658972426, 0.8872693649066419),
    (0.1705364411799497, 0.8846808176103278),
    (0.7634962513234275, 0.4358457309207533),
    (0.9259752834140167, 0.0056226911773098465),
    (0.22090405091557253, 0.14500040130773872),
    (0.4636205151855679, 0.19249574424477278),
    (0.8057632881682811, 0.250168118157608),
    (0.6785236695642043, 0.39119477830554505),
    (0.4837264739606879, 0.23045417711558214),
    (0.8786721718893166, 0.015853186240832207),
    (0.1263309724872509, 0.9185321014517236),
    (0.24969404380600335, 0.9600467657522086),
    (0.5886119367943214, 0.10948123668473264),
    (0.13373527735293878, 0.5336853876899833),
    (0.5642696742735989, 0.9801384844337597),
    (0.646401605512568, 0.3338636388089157),
    (0.05603526365085032, 0.3149530712641142),
    (0.387141492676661, 0.5792852545912592),
    (0.8634070619751958, 0.8206820685065667),
    (0.4662474858565825, 0.32647667516764145),
    (0.01801973379815025, 0.12175434785651695),
    (0.6218125565554127, 0.07860046445444713),
    (0.6573938922925594, 0.5023092428939168),
    (0.2837581848186974, 0.02576704782244421),
    (0.3044774374252185, 0.7310313422019327),
    (0.33131673439274434, 0.693896434962478),
    (0.8523694048117944, 0.2805224723356823),
    (0.6200019812032047, 0.03989814578273998),
    (0.5437394088109648, 0.3258031129949792),
    (0.4386079860370994, 0.6142798815693052),
    (0.7430581106897977, 0.49260737229959284),
    (0.3913628378102181, 0.3185830750836698),
    (0.9065498976196814, 0.02381958527497441),
    (0.6874236611131453, 0.18642068590773597),
    (0.6946411585627993, 0.36991609629423117),
    (0.3784063098306413, 0.01018756575849844),
    (0.43806374889930155, 0.2268325586117821),
    (0.7411632641820634, 0.35513151640087337),
    (0.3884706603234591, 0.34043302784114093),
    (0.08674110453583683, 0.4491174987265194),
    (0.9794883193315694, 0.11207520940235804),
    (0.7496156619797683, 0.23845386610980834),
    (0.4423888847621813, 0.17212722421686055),
    (0.2276570035864689, 0.6515924491551327),
    (0.836939257954547, 0.0499933914625984),
)

# %% [markdown]
# # Base result NSGA-II

# %%
from pymoo.core.problem import Problem
import random
import numpy as np
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.optimize import minimize

class TSPProblem(Problem):
    def __init__(self, n_cities, seed=50):
        # Define the number of variables (cities) and objectives (time and distance)
        super().__init__(n_var=n_cities, n_obj=2, n_constr=0, xl=0, xu=1)

        # Initialize the random seed for reproducibility
        if seed is not None:
            np.random.seed(seed)

        # Generate random distances and times between cities
        self.distances = np.random.uniform(0, 100, size=(n_cities, n_cities))
        self.distances = (self.distances + self.distances.T) / 2
        self.times = np.random.uniform(0, 300, size=(n_cities, n_cities))
        random.seed(None)

        # Ensure the diagonal is zero (distance/time from a city to itself is zero)
        np.fill_diagonal(self.distances, 0)
        np.fill_diagonal(self.times, 0)

    def _evaluate(self, x, out, *args, **kwargs):
        # Calculate the total distance and time for each solution in x
        distances = []
        times = []

        for route in x:
            perm = np.argsort(route)
            total_distance = 0
            total_time = 0

            for i in range(len(perm) - 1):
                total_distance += self.distances[perm[i], perm[i + 1]]
                total_time += self.times[perm[i], perm[i + 1]]

            # Add distance and time from last city back to the first city
            total_distance += self.distances[perm[-1], perm[0]]
            total_time += self.times[perm[-1], perm[0]]

            distances.append(total_distance)
            times.append(total_time)

        out["F"] = np.column_stack([distances, times])

problem = TSPProblem(100, seed=42)
print(np.shape(problem.distances))
print(np.shape(problem.times))
algorithm = NSGA2(pop_size=100)
algorithm2 = NSGA2(pop_size=50)
res_batir_1 = minimize(problem, algorithm, ("n_gen", 100), verbose=False)
res_batir_2 = minimize(problem, algorithm2, ("n_gen", 200), verbose=False)
# Out:
# (100, 100)
# (100, 100)

# %% [markdown]
# ## Development

# %%
import random

import matplotlib.pyplot as plt
import numpy as np

from genetic.algorithms import GeneticAlgorithmMO
from genetic.configurations import ProblemConfig
from genetic.crossover import OrderCrossover
from genetic.initialization import PermutationInitialization
from genetic.mutation import SwapMutation
from genetic.problems import MOTSProblem
from genetic.replacement import GenerationalReplacement
from genetic.selection import ParetoSelection

# %%
plt.style.use("dark_background")
random.seed(42)
np.random.seed(42)


def create_figure(w=12, h=8):
    fig = plt.figure(figsize=(w, h))
    ax = fig.add_subplot(111, projection="3d")
    return fig, ax


def plot_nodes(ax, nodes, elevations, color="r", size=5):
    x_coords, y_coords = zip(*nodes)
    ax.scatter(x_coords, y_coords, elevations, c=color, s=size)


def plot_path(ax, path, elevations, color="b", linewidth=1.5):
    x_path, y_path = zip(*path)
    ax.plot(x_path, y_path, elevations, color=color, linewidth=linewidth)

# %%
config = ProblemConfig(max_evaluations=1000, seed=42, output_dir="results/tsp")

# Problem
# problem = MOTSProblem(config, cities, perlin_seed=42)
problem = MOTSProblem(config, cities)

# Operators
initialization = PermutationInitialization()
selection = ParetoSelection()
crossover = OrderCrossover()
mutation = SwapMutation(mutation_rate=0.15)
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
)

# %%
from matplotlib.pyplot import imshow
from matplotlib.pyplot import subplots

fig, axes = subplots(1, 2)
axes[0].imshow(problem.dist_matrix)
axes[1].imshow(problem.time_matrix)

# %%
# Al final del todo calcula el frente de Pareto final y suele tardar bastante tiempo (16'5 min aprox)
result = ga.run()
# Out:
# Gen     10 | Evals:     550 | Pareto Size:   27 | Sample Obj: ['48.4189', '14103.9892']

# %%
print("\n" + "=" * 40)
print("RESULTS")
print("=" * 40)
print(f"Problem: {result.problem_name}")
print(f"Best distances-time:")
for pareto in result.pareto_front:
    dist, time = pareto
    print(f"  - Distance: {dist:.8f}, Time: {time:.8f}")
print(f"Evaluations used: {result.evaluations_used}")
print(f"Generations: {len(result.history)}")
print(f"Metrics:")
for metric, value in result.metrics.items():
    print(f"  - {metric}: {value}")
# Out:
# ...
# RESULTS
# ...
# Problem: MOTSProblem
# Best distances-time:
#   - Distance: 43.98207460, Time: 15601.23759068
#   - Distance: 42.91197995, Time: 16708.67527576
#   - Distance: 44.44455929, Time: 14666.39475914
#   - Distance: 46.45656938, Time: 13512.54401295
#   - Distance: 46.45656938, Time: 13512.54401295
#   - Distance: 46.45656938, Time: 13512.54401295
#   - Distance: 45.04350733, Time: 13960.96656375
#   - Distance: 46.62401713, Time: 12916.72144471
#   - Distance: 51.65006998, Time: 12396.44084231
#   - Distance: 44.96428737, Time: 14125.14890158
#   - Distance: 44.80677780, Time: 14125.80095221
#   - Distance: 45.79391273, Time: 13905.33832610
#   - Distance: 47.35121344, Time: 12806.74386460
#   - Distance: 47.40393658, Time: 12493.31728287
#   - Distance: 45.79391273, Time: 13905.33832610
#   - Distance: 47.35121344, Time: 12806.74386460
#   - Distance: 47.40393658, Time: 12493.31728287
# Evaluations used: 1000
# Generations: 0
# Metrics:
#   - n_pareto_solutions: 17
# ...

# %%
front = problem.plot_pareto_front()
front.show()

# %% [markdown]
# # New tries

# %%
from pymoo.visualization.scatter import Scatter

# %%
def print_result(result):
    print("\n" + "=" * 40)
    print("RESULTS")
    print("=" * 40)
    print(f"Problem: {result.problem_name}")
    print(f"Best distances-time:")
    for pareto in result.pareto_front:
        dist, time = pareto
        print(f"  - Distance: {dist:.8f}, Time: {time:.8f}")
    print(f"Evaluations used: {result.evaluations_used}")
    print(f"Generations: {len(result.history)}")
    print(f"Metrics:")
    for metric, value in result.metrics.items():
        print(f"  - {metric}: {value}")

def compare_with_base(new_result, res_batir_1, res_batir_2):
    scatter = Scatter()
    scatter.add(res_batir_1.F, label="NSGA2_Pop100_Ngen100")
    scatter.add(res_batir_2.F, label="NSGA2_Pop50_Ngen200")
    pareto = new_result.pareto_front
    pareto[:, 0] = pareto[:, 0] * 100
    scatter.add(pareto, label="GeneticAlgorithmMO")
    scatter.legend = True
    return scatter

# %% [markdown]
# ## Try 1

# %%
config = ProblemConfig(max_evaluations=100_000, seed=42, output_dir="results/tspmo")

# Problem
# problem = MOTSProblem(config, cities, perlin_seed=42)
problem = MOTSProblem(config, cities)

# Operators
initialization = PermutationInitialization()
selection = ParetoSelection()
crossover = OrderCrossover()
mutation = SwapMutation(mutation_rate=0.15)
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=200
)

result = ga.run()
print_result(result)
front = problem.plot_pareto_front()
front.show()
# Out:
# Gen    200 | Evals:   10050 | Pareto Size:   39 | Sample Obj: ['44.1250', '12745.5204']
# Gen    400 | Evals:   20050 | Pareto Size:   65 | Sample Obj: ['44.7522', '13131.2678']
# Gen    600 | Evals:   30050 | Pareto Size:    8 | Sample Obj: ['38.5547', '10700.5851']
# Gen    800 | Evals:   40050 | Pareto Size:   24 | Sample Obj: ['47.4310', '14257.5475']
# Gen   1000 | Evals:   50050 | Pareto Size:   21 | Sample Obj: ['38.7316', '10502.3912']
# Gen   1200 | Evals:   60050 | Pareto Size:   21 | Sample Obj: ['38.2028', '9666.7047']
# Gen   1400 | Evals:   70050 | Pareto Size:   44 | Sample Obj: ['37.8575', '9374.9124']
# Gen   1600 | Evals:   80050 | Pareto Size:   59 | Sample Obj: ['37.0162', '9839.2558']
# Gen   1800 | Evals:   90050 | Pareto Size:   74 | Sample Obj: ['49.3432', '13935.1544']
#
# ...
# RESULTS
# ...
# Problem: MOTSProblem
# Best distances-time:
#   - Distance: 40.02631544, Time: 8414.22348628
#   - Distance: 39.41606416, Time: 8455.02650279
# ...

# %%
scatter = compare_with_base(result, res_batir_1, res_batir_2)
scatter.show()

# %% [markdown]
# ## Try 2 InversionMutation

# %%
from genetic.mutation import InversionMutation

# %%
config = ProblemConfig(max_evaluations=100000, seed=42, output_dir="results/tspmo")

problem = MOTSProblem(config, cities)

# Operators
initialization = PermutationInitialization()
selection = ParetoSelection()
crossover = OrderCrossover()
mutation = InversionMutation(mutation_rate=0.1)
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=200
)

result = ga.run()
scatter = compare_with_base(result, res_batir_1, res_batir_2)
scatter.show()
# Out:
# Gen    200 | Evals:   10050 | Pareto Size:  258 | Sample Obj: ['45.1993', '13554.3368']
# Gen    400 | Evals:   20050 | Pareto Size:  111 | Sample Obj: ['46.2632', '13485.7559']
# Gen    600 | Evals:   30050 | Pareto Size:   16 | Sample Obj: ['44.5919', '12041.8057']
# Gen    800 | Evals:   40050 | Pareto Size:   11 | Sample Obj: ['44.3801', '11846.3060']
# Gen   1000 | Evals:   50050 | Pareto Size:   12 | Sample Obj: ['48.1862', '14022.0691']
# Gen   1200 | Evals:   60050 | Pareto Size:    9 | Sample Obj: ['44.9594', '12104.0699']
# Gen   1400 | Evals:   70050 | Pareto Size:   13 | Sample Obj: ['44.4353', '11870.0933']
# Gen   1600 | Evals:   80050 | Pareto Size:   13 | Sample Obj: ['44.0391', '12041.4860']
# Gen   1800 | Evals:   90050 | Pareto Size:   28 | Sample Obj: ['45.0755', '11779.3702']

# %% [markdown]
# # try 3 SwapMutation

# %%
config = ProblemConfig(max_evaluations=100000, seed=42, output_dir="results/tspmo")

problem = MOTSProblem(config, cities)

# Operators
initialization = PermutationInitialization()
selection = ParetoSelection()
crossover = OrderCrossover()
mutation = SwapMutation(mutation_rate=0.15)
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=100,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=100
)

result = ga.run()
scatter = compare_with_base(result, res_batir_1, res_batir_2)
scatter.show()
# Out:
# Gen    100 | Evals:   10100 | Pareto Size:   11 | Sample Obj: ['42.2400', '12960.6276']
# Gen    200 | Evals:   20100 | Pareto Size:   42 | Sample Obj: ['41.2329', '10367.6203']
# Gen    300 | Evals:   30100 | Pareto Size:   44 | Sample Obj: ['43.1118', '9904.2559']
# Gen    400 | Evals:   40100 | Pareto Size:   32 | Sample Obj: ['46.7418', '11607.4521']
# Gen    500 | Evals:   50100 | Pareto Size:  121 | Sample Obj: ['39.5480', '11107.0527']
# Gen    600 | Evals:   60100 | Pareto Size:   93 | Sample Obj: ['48.2473', '13641.8281']
# Gen    700 | Evals:   70100 | Pareto Size:   74 | Sample Obj: ['37.4952', '10965.4522']
# Gen    800 | Evals:   80100 | Pareto Size:   62 | Sample Obj: ['37.1146', '10568.6508']
# Gen    900 | Evals:   90100 | Pareto Size:   35 | Sample Obj: ['38.2529', '10015.0846']

# %% [markdown]
# ## Try 4: Configuración Optimizada
# Combinación de operadores óptimos para TSP:
# - **EdgeRecombinationCrossover (ERX)**: Preserva el máximo número de aristas de ambos padres
# - **InversionMutation**: Equivalente a 2-opt, elimina cruces y mejora estructura geométrica
# - **NeighborInitialization**: Inicialización heurística con k-nearest neighbors para mejor calidad inicial
# - **Mayor población**: 150 individuos para mejor exploración del frente de Pareto

# %%
from genetic.crossover import EdgeRecombinationCrossover, PMXCrossover
from genetic.initialization import NeighborInitialization, DiverseNNInitialization

# %%
config = ProblemConfig(max_evaluations=100000, seed=42, output_dir="results/tspmo_optimized")

problem = MOTSProblem(config, cities)

# Operadores optimizados para TSP multiobjetivo
initialization = NeighborInitialization(k_best=3)  # Inicialización heurística con diversidad
selection = ParetoSelection()
crossover = EdgeRecombinationCrossover()  # Preserva aristas - ideal para TSP
mutation = InversionMutation(mutation_rate=0.2)  # 2-opt implícito - muy efectivo
replacement = GenerationalReplacement()

# Genetic Algorithm con población más grande
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=150,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=100
)

result = ga.run()
scatter = compare_with_base(result, res_batir_1, res_batir_2)
scatter.show()
# Out:
# Gen    100 | Evals:   15150 | Pareto Size:   17 | Sample Obj: ['29.0502', '11850.7019']
# Gen    200 | Evals:   30150 | Pareto Size:   15 | Sample Obj: ['29.9633', '13208.5692']
# Gen    300 | Evals:   45150 | Pareto Size:   16 | Sample Obj: ['30.9957', '12649.3750']
# Gen    400 | Evals:   60150 | Pareto Size:   17 | Sample Obj: ['30.0797', '11718.7233']
# Gen    500 | Evals:   75150 | Pareto Size:   17 | Sample Obj: ['26.5862', '12753.7323']
# Gen    600 | Evals:   90150 | Pareto Size:   17 | Sample Obj: ['29.0211', '10777.8012']

# %% [markdown]
# ## Try 5: PMX + Mutación Combinada
# Alternativa con PMXCrossover que también es muy efectivo para TSP, combinando dos mutaciones.

# %%
from genetic.mutation import CombinedMutation

config = ProblemConfig(max_evaluations=28000, seed=42, output_dir="results/tspmo_pmx")

problem = MOTSProblem(config, cities)

# Operadores con PMX y mutación combinada
initialization = NeighborInitialization(k_best=5)  # Mayor diversidad en inicialización
selection = ParetoSelection()
crossover = PMXCrossover()  # Partially Mapped Crossover - muy efectivo para TSP

# Mutación combinada: primero inversión (explotación), luego swap (exploración)
mutation = CombinedMutation([
    InversionMutation(mutation_rate=0.15),  # 2-opt para mejora local
    SwapMutation(mutation_rate=0.05),        # Diversificación ocasional
])
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=120,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=100
)

result = ga.run()
scatter = compare_with_base(result, res_batir_1, res_batir_2)
scatter.show()
# Out:
# [autoreload of genetic.problems failed: Traceback (most recent call last):
#   File "c:\Users\Yago\Desktop\MAADM\3 Computación Evolutiva y Bioinspirada\practica_biocomp\.venv\Lib\site-packages\IPython\extensions\autoreload.py", line 322, in check
#     elif self.deduper_reloader.maybe_reload_module(m):
#          ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "c:\Users\Yago\Desktop\MAADM\3 Computación Evolutiva y Bioinspirada\practica_biocomp\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 546, in maybe_reload_module
#     new_source_code = f.read()
#   File "C:\Users\Yago\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 16799: character maps to <undefined>
# ]
# ...

# %% [markdown]
# ## Try 6: Configuración Óptima Final
# Combinación final optimizada para TSP multiobjetivo:
# - **DiverseNNInitialization**: Inicialización determinista con diversidad máxima (cada individuo empieza en ciudad diferente)
# - **EdgeRecombinationCrossover**: Preserva aristas de ambos padres - el mejor para TSP
# - **CombinedMutation**: InversionMutation (2-opt) + SwapMutation para balance explotación/exploración
# - **Población grande (200)**: Mayor diversidad en el frente de Pareto

# %%
from genetic.mutation import CombinedMutation, InversionMutation, SwapMutation
from genetic.initialization import DiverseNNInitialization
from genetic.crossover import EdgeRecombinationCrossover
from genetic.replacement import GenerationalReplacement

config = ProblemConfig(max_evaluations=100000, seed=42, output_dir="results/tspmo_final")

problem = MOTSProblem(config, cities)

# Operadores óptimos para TSP multiobjetivo
initialization = DiverseNNInitialization()  # Máxima diversidad - cada individuo inicia en ciudad diferente
selection = ParetoSelection()
crossover = EdgeRecombinationCrossover()  # Preserva aristas - el mejor crossover para TSP

# Mutación combinada optimizada
mutation = CombinedMutation([
    InversionMutation(mutation_rate=0.25),  # 2-opt agresivo para explotación
    SwapMutation(mutation_rate=0.08),        # Diversificación moderada
])
replacement = GenerationalReplacement()

# Genetic Algorithm con población grande para mejor cobertura del frente Pareto
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=200,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=50
)

result = ga.run()
print_result(result)
scatter = compare_with_base(result, res_batir_1, res_batir_2)
scatter.show()
# Out:
# Gen     50 | Evals:   10200 | Pareto Size:   22 | Sample Obj: ['30.7118', '12610.9517']
# Gen    100 | Evals:   20200 | Pareto Size:   24 | Sample Obj: ['30.8754', '12722.1466']
# Gen    150 | Evals:   30200 | Pareto Size:   23 | Sample Obj: ['29.6076', '11631.3359']
# Gen    200 | Evals:   40200 | Pareto Size:   24 | Sample Obj: ['31.5552', '12942.9132']
# Gen    250 | Evals:   50200 | Pareto Size:   23 | Sample Obj: ['32.3052', '13680.5882']
# Gen    300 | Evals:   60200 | Pareto Size:   23 | Sample Obj: ['30.5387', '12985.0218']
# Gen    350 | Evals:   70200 | Pareto Size:   25 | Sample Obj: ['31.2422', '12503.4193']
# Gen    400 | Evals:   80200 | Pareto Size:   25 | Sample Obj: ['31.3273', '11721.4338']
# Gen    450 | Evals:   90200 | Pareto Size:   25 | Sample Obj: ['28.5712', '12932.2706']
#
# ...
# RESULTS
# ...
# Problem: MOTSProblem
# Best distances-time:
#   - Distance: 8.97767730, Time: 13659.11685510
#   - Distance: 8.93566649, Time: 13880.47520745
# ...

# %%
problem.get_nsga2_result(100, 42, verbose=True)

fronts = problem.plot_pareto_front()
fronts.show()
# Out:
# ...
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ...
#      1 |      100 |      3 |             - |             -
#      2 |      200 |      7 |  0.1283845260 |         ideal
#      3 |      300 |      6 |  0.1517257406 |         ideal
#      4 |      400 |      6 |  0.2320146698 |         ideal
#      5 |      500 |      7 |  0.0264470732 |             f
#      6 |      600 |      9 |  0.0236239439 |         ideal
#      7 |      700 |      9 |  0.1383946683 |         ideal
#      8 |      800 |      6 |  0.1462310585 |         ideal
#      9 |      900 |      7 |  0.2176238488 |         ideal
#     10 |     1000 |      6 |  0.0644670735 |         ideal
#     11 |     1100 |     10 |  0.0407950056 |             f
#     12 |     1200 |      6 |  0.2123698499 |         ideal
#     13 |     1300 |      8 |  0.1195413889 |         ideal
#     14 |     1400 |     10 |  0.0490740251 |             f
#     15 |     1500 |     13 |  0.0558222168 |         ideal
# ...
