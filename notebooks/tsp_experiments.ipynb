# %% [markdown]
# # Initializations

# %%
cd ..
# Out:
# c:\Users\Yago\Desktop\MAADM\3 Computación Evolutiva y Bioinspirada\practica_biocomp

# %%
# %load_ext autoreload
# %autoreload 2

# %%
cities = (
    (0.8744058793117488, 0.30207179832703746),
    (0.6901572276474558, 0.8203362566663311),
    (0.7793458478083026, 0.09728979746351918),
    (0.7483358474304422, 0.4563419482458657),
    (0.4556164527790729, 0.12863149772605698),
    (0.1837236688553453, 0.23773749495644914),
    (0.806151832654163, 0.3288366900529254),
    (0.6222702185205219, 0.6019431085670109),
    (0.21886861543988367, 0.6980104036528004),
    (0.9706096813038716, 0.054871876245520146),
    (0.13881496219356027, 0.048489530185603646),
    (0.08511086492841424, 0.9123075505436051),
    (0.45436952164297595, 0.4731540740573398),
    (0.8986352255038935, 0.5116579750591849),
    (0.9539248970461742, 0.7530784036308166),
    (0.6321102985156373, 0.13575967095580344),
    (0.31130918313591205, 0.8545457319320597),
    (0.025897479791937017, 0.7854526665590987),
    (0.31414095045738066, 0.051421702103483846),
    (0.2739561013272712, 0.1970964027924862),
    (0.22762328443470214, 0.627414210742153),
    (0.44920042912037383, 0.18835427573438068),
    (0.2793138301174244, 0.9103956650199608),
    (0.005128451667189338, 0.4655718085045638),
    (0.9222718335261915, 0.8613103704784812),
    (0.49352498279326595, 0.28652416807644077),
    (0.5560886356057152, 0.034564925228364185),
    (0.0048939219846825255, 0.8635350555457212),
    (0.7824462381771976, 0.09355415747424733),
    (0.2973635133076785, 0.037580527218207815),
    (0.659068210692151, 0.5602321147981546),
    (0.43549418718677035, 0.6241289474799954),
    (0.25580657871099755, 0.519726015381631),
    (0.5950780852425872, 0.3193476592023645),
    (0.15763623266223903, 0.18210618406479095),
    (0.3434173147566393, 0.32992255868483356),
    (0.06451313705472006, 0.12606114349173192),
    (0.23212286400737547, 0.3945559700824013),
    (0.955507285594692, 0.02296933408938162),
    (0.7459955912073274, 0.1385374827130177),
    (0.46365765315595475, 0.6132297411379687),
    (0.20196772698059162, 0.046358747430397584),
    (0.2980093518214506, 0.36041197123227897),
    (0.7533459401199348, 0.6610562232191091),
    (0.323433933838161, 0.5068337090138902),
    (0.062138830138457, 0.7177455044259695),
    (0.47467832142010535, 0.17692718986260936),
    (0.2415634321550142, 0.500852093941769),
    (0.3441878827094532, 0.2604351258948506),
    (0.5445252142594251, 0.7295590645635646),
    (0.25391391610860914, 0.7641244059389684),
    (0.2630560480211699, 0.010670642241309536),
    (0.2092202940037915, 0.7415775443241935),
    (0.0031474687633804566, 0.6974574785842637),
    (0.4952329615559806, 0.9311775894780175),
    (0.1978488658972426, 0.8872693649066419),
    (0.1705364411799497, 0.8846808176103278),
    (0.7634962513234275, 0.4358457309207533),
    (0.9259752834140167, 0.0056226911773098465),
    (0.22090405091557253, 0.14500040130773872),
    (0.4636205151855679, 0.19249574424477278),
    (0.8057632881682811, 0.250168118157608),
    (0.6785236695642043, 0.39119477830554505),
    (0.4837264739606879, 0.23045417711558214),
    (0.8786721718893166, 0.015853186240832207),
    (0.1263309724872509, 0.9185321014517236),
    (0.24969404380600335, 0.9600467657522086),
    (0.5886119367943214, 0.10948123668473264),
    (0.13373527735293878, 0.5336853876899833),
    (0.5642696742735989, 0.9801384844337597),
    (0.646401605512568, 0.3338636388089157),
    (0.05603526365085032, 0.3149530712641142),
    (0.387141492676661, 0.5792852545912592),
    (0.8634070619751958, 0.8206820685065667),
    (0.4662474858565825, 0.32647667516764145),
    (0.01801973379815025, 0.12175434785651695),
    (0.6218125565554127, 0.07860046445444713),
    (0.6573938922925594, 0.5023092428939168),
    (0.2837581848186974, 0.02576704782244421),
    (0.3044774374252185, 0.7310313422019327),
    (0.33131673439274434, 0.693896434962478),
    (0.8523694048117944, 0.2805224723356823),
    (0.6200019812032047, 0.03989814578273998),
    (0.5437394088109648, 0.3258031129949792),
    (0.4386079860370994, 0.6142798815693052),
    (0.7430581106897977, 0.49260737229959284),
    (0.3913628378102181, 0.3185830750836698),
    (0.9065498976196814, 0.02381958527497441),
    (0.6874236611131453, 0.18642068590773597),
    (0.6946411585627993, 0.36991609629423117),
    (0.3784063098306413, 0.01018756575849844),
    (0.43806374889930155, 0.2268325586117821),
    (0.7411632641820634, 0.35513151640087337),
    (0.3884706603234591, 0.34043302784114093),
    (0.08674110453583683, 0.4491174987265194),
    (0.9794883193315694, 0.11207520940235804),
    (0.7496156619797683, 0.23845386610980834),
    (0.4423888847621813, 0.17212722421686055),
    (0.2276570035864689, 0.6515924491551327),
    (0.836939257954547, 0.0499933914625984),
)

# %% [markdown]
# ### Class imports

# %%
import random

import matplotlib.pyplot as plt
import numpy as np

from aco import AntColony
from genetic.algorithms import GeneticAlgorithmSO
from genetic.configurations import ProblemConfig
from genetic.crossover import OrderCrossover, PMXCrossover, CycleCrossover, EdgeRecombinationCrossover
from genetic.initialization import PermutationInitialization, DiverseNNInitialization, NeighborInitialization
from genetic.mutation import SwapMutation, TwoOptSearchMutation, ScrambleMutation, InversionMutation
from genetic.problems import TSProblem, TSProblem
from genetic.replacement import GenerationalReplacement, ElitistReplacement, MuPlusLambdaReplacement
from genetic.selection import TournamentSelection

# %% [markdown]
# ## Plots

# %%
plt.style.use("dark_background")
random.seed(42)
np.random.seed(42)


def create_figure(w=12, h=8):
    fig, ax = plt.subplots(figsize=(w, h))
    ax.axis("off")
    return fig, ax


def plot_nodes(ax, nodes, color="r", size=5):
    for x, y in nodes:
        ax.plot(x, y, ".", color=color, markersize=size)


def plot_path(ax, path, color="b", linewidth=1.5):
    for i in range(len(path) - 1):
        x = (path[i][0], path[i + 1][0])
        y = (path[i][1], path[i + 1][1])
        ax.plot(x, y, color=color, linewidth=linewidth)

# %%
# Plot evolution
def plot_evolution(mean_history, best_history, worst_history):
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.plot(best_history, label="Best", color="cyan")
    ax.plot(mean_history, label="Mean", color="yellow")
    ax.plot(worst_history, label="Worst", color="red")
    ax.set_xlabel("Generation")
    ax.set_ylabel("Fitness")
    ax.set_title("Evolution of Fitness over Generations")
    ax.set_ylim(bottom=0)
    ax.legend()
    plt.show()

def plot_best(best_solution, best_fitness):
    cities_solution = [cities[idx] for idx in best_solution]
    cities_solution.append(cities_solution[0])

    fig, ax = create_figure()
    plot_nodes(ax, cities)
    plot_path(ax, cities_solution)
    fig.text(0.5, 0.02, f"Total distance: {best_fitness:.4f}", ha="center")

# %% [markdown]
# # Genetic

# %% [markdown]
# ## First try
#
# Trounament, 3, mutation_sate = 0.15, population 50

# %%
config = ProblemConfig(max_evaluations=1000000, seed=38, output_dir="results/tsp")

# Problem
problem = TSProblem(config, cities)

# Operators
initialization = PermutationInitialization()
selection = TournamentSelection(tournament_size=3)
crossover = OrderCrossover()
mutation = SwapMutation(mutation_rate=0.15)
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmSO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=1000
)

# %%
print("=" * 80)
print("OPTIMIZING TRAVELING SALESMAN PROBLEM")
print("=" * 80)
result = ga.run()
# Out:
# ...
# OPTIMIZING TRAVELING SALESMAN PROBLEM
# ...
# Gen   1000 | Evals:   50050 | Best Global: 36.82943 | Current Population: 43.74771 ± 3.987e+00
# Gen   2000 | Evals:  100050 | Best Global: 31.06776 | Current Population: 35.93591 ± 6.506e+00
# Gen   3000 | Evals:  150050 | Best Global: 27.90462 | Current Population: 37.74357 ± 8.109e+00
# Gen   4000 | Evals:  200050 | Best Global: 30.65122 | Current Population: 38.10239 ± 7.385e+00
# Gen   5000 | Evals:  250050 | Best Global: 29.18335 | Current Population: 36.09332 ± 7.709e+00
# Gen   6000 | Evals:  300050 | Best Global: 26.59028 | Current Population: 36.21429 ± 8.696e+00
# Gen   7000 | Evals:  350050 | Best Global: 28.02154 | Current Population: 35.33093 ± 7.302e+00
# Gen   8000 | Evals:  400050 | Best Global: 26.60445 | Current Population: 35.59272 ± 8.875e+00
# Gen   9000 | Evals:  450050 | Best Global: 26.96514 | Current Population: 32.94313 ± 8.546e+00
# ...

# %%
print("\n" + "=" * 40)
print("RESULTS")
print("=" * 40)
print(f"Problem: {result.problem_name}")
print(f"Best fitness: {result.best_fitness:.8f}")
print(f"Best solution: cities={result.best_solution}")
print(f"Best distance: {problem._sol_distance(result.best_solution):.8f}")
print(f"Evaluations used: {result.evaluations_used}")
print(f"Generations: {len(result.history)}")
# Out:
# ...
# RESULTS
# ...
# Problem: TSProblem
# Best fitness: 23.78830237
# ...

# %%
cities_solution = [cities[idx] for idx in result.best_solution]
cities_solution.append(cities_solution[0])

fig, ax = create_figure()
plot_nodes(ax, cities)
plot_path(ax, cities_solution)

# %% [markdown]
# ## Second try

# %%
config = ProblemConfig(max_evaluations=1000000, seed=38, output_dir="results/tsp")

# Problem
problem = TSProblem(config, cities, minimize=True)

# Operators
initialization = PermutationInitialization()
selection = TournamentSelection(tournament_size=10)
crossover = OrderCrossover()
mutation = SwapMutation(mutation_rate=0.5)
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmSO(
    problem=problem,
    population_size=100,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=500
)

# %%
print("=" * 80)
print("OPTIMIZING TRAVELING SALESMAN PROBLEM")
print("=" * 80)
result = ga.run()
# Out:
# ...
# OPTIMIZING TRAVELING SALESMAN PROBLEM
# ...
# Gen     10 | Evals:    1100 | Best Global: 41.78468 | Current Population: 45.48287 ± 2.775e+00
# Gen     20 | Evals:    2100 | Best Global: 40.95593 | Current Population: 46.35508 ± 3.254e+00
# Gen     30 | Evals:    3100 | Best Global: 39.42438 | Current Population: 45.25108 ± 3.622e+00
# Gen     40 | Evals:    4100 | Best Global: 38.81234 | Current Population: 45.94028 ± 3.283e+00
# Gen     50 | Evals:    5100 | Best Global: 38.32146 | Current Population: 45.44154 ± 4.040e+00
# Gen     60 | Evals:    6100 | Best Global: 37.37190 | Current Population: 44.88438 ± 4.194e+00
# Gen     70 | Evals:    7100 | Best Global: 36.72150 | Current Population: 44.15603 ± 4.221e+00
# Gen     80 | Evals:    8100 | Best Global: 36.94988 | Current Population: 43.42777 ± 4.167e+00
# Gen     90 | Evals:    9100 | Best Global: 35.33146 | Current Population: 42.61348 ± 4.749e+00
# ...

# %%
cities_solution = [cities[idx] for idx in result.best_solution]
cities_solution.append(cities_solution[0])

fig, ax = create_figure()
plot_nodes(ax, cities)
plot_path(ax, cities_solution)

# %% [markdown]
# ## Third try, now using distance and creating traces

# %%
config = ProblemConfig(max_evaluations=1000000, seed=38, output_dir="results/tsp")

# Problem
problem = TSProblem(config, cities, minimize=True)

# Operators
initialization = PermutationInitialization()
selection = TournamentSelection(tournament_size=10)
crossover = OrderCrossover()
mutation = SwapMutation(mutation_rate=0.5)
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmSO(
    problem=problem,
    population_size=100,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=1000
)

# %%
print("=" * 80)
print("OPTIMIZING TRAVELING SALESMAN PROBLEM")
print("=" * 80)
result = ga.run()
# Out:
# ...
# OPTIMIZING TRAVELING SALESMAN PROBLEM
# ...
# Gen   1000 | Evals:  100100 | Best Global: 26.91597 | Current Population: 38.05755 ± 7.610e+00
# Gen   2000 | Evals:  200100 | Best Global: 27.26526 | Current Population: 38.57202 ± 8.541e+00
# Gen   3000 | Evals:  300100 | Best Global: 25.15583 | Current Population: 33.89040 ± 7.001e+00
# Gen   4000 | Evals:  400100 | Best Global: 24.63563 | Current Population: 35.81937 ± 8.407e+00
# Gen   5000 | Evals:  500100 | Best Global: 24.35684 | Current Population: 40.40367 ± 7.236e+00
# Gen   6000 | Evals:  600100 | Best Global: 21.99762 | Current Population: 35.18409 ± 1.029e+01
# Gen   7000 | Evals:  700100 | Best Global: 20.18890 | Current Population: 33.41596 ± 9.517e+00
# Gen   8000 | Evals:  800100 | Best Global: 19.91979 | Current Population: 32.70186 ± 1.053e+01
# Gen   9000 | Evals:  900100 | Best Global: 20.05025 | Current Population: 34.16692 ± 1.081e+01

# %%
plot_evolution(
    problem.mean_history,
    problem.best_history,
    problem.worst_history,
)

# %% [markdown]
# ## Fourth try, changing replacement

# %%
config = ProblemConfig(max_evaluations=1000000, seed=38, output_dir="results/tsp")

# Problem
problem = TSProblem(config, cities, minimize=True)

# Operators
initialization = PermutationInitialization()
selection = TournamentSelection(tournament_size=50)
crossover = OrderCrossover()
mutation = SwapMutation(mutation_rate=1)
replacement = ElitistReplacement(elite_size=15)

# Genetic Algorithm
ga = GeneticAlgorithmSO(
    problem=problem,
    population_size=100,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=1000
)

# %%
print("=" * 80)
print("OPTIMIZING TRAVELING SALESMAN PROBLEM")
print("=" * 80)
result = ga.run()
# Out:
# ...
# OPTIMIZING TRAVELING SALESMAN PROBLEM
# ...
# Gen   1000 | Evals:   85100 | Best Global: 21.62233 | Current Population: 33.35724 ± 8.572e+00
# Gen   2000 | Evals:  170100 | Best Global: 18.95544 | Current Population: 31.83346 ± 9.418e+00
# Gen   3000 | Evals:  255100 | Best Global: 16.34029 | Current Population: 34.10240 ± 1.214e+01
# Gen   4000 | Evals:  340100 | Best Global: 15.15480 | Current Population: 29.82392 ± 1.151e+01
# Gen   5000 | Evals:  425100 | Best Global: 14.69374 | Current Population: 30.03886 ± 1.097e+01
# Gen   6000 | Evals:  510100 | Best Global: 14.29079 | Current Population: 31.02031 ± 1.224e+01
# Gen   7000 | Evals:  595100 | Best Global: 13.86308 | Current Population: 31.32630 ± 1.330e+01
# Gen   8000 | Evals:  680100 | Best Global: 13.59850 | Current Population: 30.52694 ± 1.231e+01
# Gen   9000 | Evals:  765100 | Best Global: 12.89721 | Current Population: 30.96506 ± 1.262e+01
# ...

# %%
plot_evolution(
    problem.mean_history,
    problem.best_history,
    problem.worst_history,
)

# %%
plot_best(problem.best_solution, problem.best_fitness)

# %% [markdown]
# ## Fifth try, changing hyperparameters during execution

# %%
config = ProblemConfig(max_evaluations=1000000, seed=38, output_dir="results/tsp")

# Problem
problem = TSProblem(config, cities, minimize=True)

# Operators
initialization = PermutationInitialization()
selection = TournamentSelection(tournament_size=50)
crossover = OrderCrossover()
mutation = SwapMutation(mutation_rate=1)
replacement = ElitistReplacement(elite_size=15)

# Genetic Algorithm
ga = GeneticAlgorithmSO(
    problem=problem,
    population_size=100,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=100
)

# %%
result = ga.run(num_iterations=2000)
# Out:
# Gen    100 | Evals:    8600 | Best Global: 27.45720 | Current Population: 36.78435 ± 6.630e+00
# Gen    200 | Evals:   17100 | Best Global: 26.95467 | Current Population: 37.76418 ± 7.246e+00
# Gen    300 | Evals:   25600 | Best Global: 26.49215 | Current Population: 36.90728 ± 7.528e+00
# Gen    400 | Evals:   34100 | Best Global: 26.07673 | Current Population: 36.88087 ± 7.456e+00
# Gen    500 | Evals:   42600 | Best Global: 25.13266 | Current Population: 37.22677 ± 8.089e+00
# Gen    600 | Evals:   51100 | Best Global: 24.12413 | Current Population: 35.01575 ± 7.787e+00
# Gen    700 | Evals:   59600 | Best Global: 23.24928 | Current Population: 35.74125 ± 9.304e+00
# Gen    800 | Evals:   68100 | Best Global: 22.67425 | Current Population: 36.44689 ± 8.933e+00
# Gen    900 | Evals:   76600 | Best Global: 22.22982 | Current Population: 32.01442 ± 7.961e+00
# Gen   1000 | Evals:   85100 | Best Global: 21.62233 | Current Population: 33.35724 ± 8.572e+00
# ...

# %%
plot_evolution(
    problem.mean_history,
    problem.best_history,
    problem.worst_history,
)

# %%
config = ProblemConfig(max_evaluations=1000000, seed=38, output_dir="results/tsp")

# Problem
baseline_problem = TSProblem(config, cities, minimize=True)

# Operators
initialization = PermutationInitialization()
selection = TournamentSelection(tournament_size=50)
crossover = OrderCrossover()
mutation = SwapMutation(mutation_rate=1)
replacement = ElitistReplacement(elite_size=15)

# Genetic Algorithm
baseline = GeneticAlgorithmSO(
    problem=baseline_problem,
    population_size=100,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=500
)
res = baseline.run(num_iterations=2000)
plot_evolution(
    baseline_problem.mean_history,
    baseline_problem.best_history,
    baseline_problem.worst_history,
)
# Out:
# Gen    500 | Evals:   42600 | Best Global: 25.13266 | Current Population: 37.22677 ± 8.089e+00
# Gen   1000 | Evals:   85100 | Best Global: 21.62233 | Current Population: 33.35724 ± 8.572e+00
# Gen   1500 | Evals:  127600 | Best Global: 20.00246 | Current Population: 35.89520 ± 9.921e+00
# Gen   2000 | Evals:  170100 | Best Global: 18.95544 | Current Population: 31.83346 ± 9.418e+00

# %% [markdown]
# ## Sixth try

# %%
import copy

# %%
ga_backup = copy.deepcopy(ga)
prob_backup = copy.deepcopy(problem)

# %%
ga.replacement = ElitistReplacement(elite_size=3)
ga.selection = TournamentSelection(tournament_size=2)

# %%
res = ga.run(num_iterations=2000)
# Out:
# Gen   2100 | Evals:  179800 | Best Global: 18.95544 | Current Population: 40.17945 ± 6.954e+00
# Gen   2200 | Evals:  189500 | Best Global: 18.95544 | Current Population: 42.94701 ± 5.543e+00
# Gen   2300 | Evals:  199200 | Best Global: 18.77675 | Current Population: 42.09204 ± 6.901e+00
# Gen   2400 | Evals:  208900 | Best Global: 18.71049 | Current Population: 42.79759 ± 6.599e+00
# Gen   2500 | Evals:  218600 | Best Global: 18.63024 | Current Population: 42.47885 ± 6.720e+00
# Gen   2600 | Evals:  228300 | Best Global: 18.63024 | Current Population: 42.85886 ± 6.273e+00
# Gen   2700 | Evals:  238000 | Best Global: 18.63024 | Current Population: 41.92864 ± 6.843e+00
# Gen   2800 | Evals:  247700 | Best Global: 18.51625 | Current Population: 40.66206 ± 7.040e+00
# Gen   2900 | Evals:  257400 | Best Global: 18.51625 | Current Population: 42.85686 ± 6.249e+00
# Gen   3000 | Evals:  267100 | Best Global: 18.51625 | Current Population: 43.09138 ± 5.743e+00
# ...

# %%
res = ga.run(num_iterations=4000)
# Out:
# Gen   4100 | Evals:  373800 | Best Global: 18.47963 | Current Population: 42.60743 ± 6.474e+00
# Gen   4200 | Evals:  383500 | Best Global: 18.44579 | Current Population: 40.91652 ± 6.468e+00
# Gen   4300 | Evals:  393200 | Best Global: 18.37503 | Current Population: 42.99714 ± 6.448e+00
# Gen   4400 | Evals:  402900 | Best Global: 18.37503 | Current Population: 43.47339 ± 5.983e+00
# Gen   4500 | Evals:  412600 | Best Global: 18.37503 | Current Population: 41.66361 ± 6.642e+00
# Gen   4600 | Evals:  422300 | Best Global: 18.37503 | Current Population: 42.95136 ± 6.447e+00
# Gen   4700 | Evals:  432000 | Best Global: 18.37503 | Current Population: 41.73447 ± 5.979e+00
# Gen   4800 | Evals:  441700 | Best Global: 18.37503 | Current Population: 42.49969 ± 6.227e+00
# Gen   4900 | Evals:  451400 | Best Global: 18.35912 | Current Population: 42.35045 ± 5.782e+00
# Gen   5000 | Evals:  461100 | Best Global: 18.35912 | Current Population: 41.85744 ± 6.390e+00
# ...

# %%
ga.replacement = ElitistReplacement(elite_size=1)
res = ga.run(num_iterations=2000)
# Out:
# Gen   8100 | Evals:  762000 | Best Global: 18.00366 | Current Population: 43.77953 ± 5.114e+00
# Gen   8200 | Evals:  771900 | Best Global: 18.00366 | Current Population: 43.01260 ± 5.266e+00
# Gen   8300 | Evals:  781800 | Best Global: 17.94880 | Current Population: 42.90357 ± 3.826e+00
# Gen   8400 | Evals:  791700 | Best Global: 17.85378 | Current Population: 43.75037 ± 5.100e+00
# Gen   8500 | Evals:  801600 | Best Global: 17.76890 | Current Population: 43.79374 ± 4.029e+00
# Gen   8600 | Evals:  811500 | Best Global: 17.76890 | Current Population: 42.64529 ± 5.373e+00
# Gen   8700 | Evals:  821400 | Best Global: 17.76890 | Current Population: 43.25456 ± 4.189e+00
# Gen   8800 | Evals:  831300 | Best Global: 17.76890 | Current Population: 43.67760 ± 5.039e+00
# Gen   8900 | Evals:  841200 | Best Global: 17.76890 | Current Population: 44.24279 ± 4.654e+00
# Gen   9000 | Evals:  851100 | Best Global: 17.76890 | Current Population: 42.89386 ± 4.420e+00
# ...

# %%
plot_evolution(
    problem.mean_history,
    problem.best_history,
    problem.worst_history,
)

# %%
plot_best(problem.best_solution, problem.best_fitness)

# %% [markdown]
# ## Otras pruebas
# Dejo este codigo por aqui para ir probando algunas cosas que estoy desarollando:

# %%
config = ProblemConfig(max_evaluations=1000000, seed=38, output_dir="results/tsp")

# Problem
baseline_problem = TSProblem(config, cities, minimize=True)

# Operators
initialization = NeighborInitialization()
selection = TournamentSelection(tournament_size=50)
crossover = OrderCrossover()
mutation = SwapMutation(mutation_rate=1)
replacement = ElitistReplacement(elite_size=15)

# Genetic Algorithm
baseline = GeneticAlgorithmSO(
    problem=baseline_problem,
    population_size=100,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=500
)

res = baseline.run(num_iterations=2000)
plot_evolution(
    baseline_problem.mean_history,
    baseline_problem.best_history,
    baseline_problem.worst_history,
)
# Out:
# Gen    500 | Evals:   42600 | Best Global: 13.02488 | Current Population: 28.40121 ± 1.137e+01
# Gen   1000 | Evals:   85100 | Best Global: 12.65303 | Current Population: 28.82391 ± 1.121e+01
# Gen   1500 | Evals:  127600 | Best Global: 12.60533 | Current Population: 26.57792 ± 1.049e+01
# Gen   2000 | Evals:  170100 | Best Global: 12.28000 | Current Population: 28.21000 ± 1.034e+01

# %% [markdown]
# ### DiverseNNInitialization
# Incializacion determinsita que siempre elige la siguiente ciudad más cercana

# %%
config = ProblemConfig(max_evaluations=1000000, seed=38, output_dir="results/tsp")

# Problem
diverse_ini_problem = TSProblem(config, cities, minimize=True)

# Operators
initialization = DiverseNNInitialization()
selection = TournamentSelection(tournament_size=50)
crossover = OrderCrossover()
mutation = SwapMutation(mutation_rate=1)
replacement = ElitistReplacement(elite_size=15)

# Genetic Algorithm
diverse_ini = GeneticAlgorithmSO(
    problem=diverse_ini_problem,
    population_size=100,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=500
)

res = diverse_ini.run(num_iterations=2000)
plot_evolution(
    diverse_ini_problem.mean_history,
    diverse_ini_problem.best_history,
    diverse_ini_problem.worst_history,
)
plot_best(res.best_solution, res.best_fitness)
# Out:
# Gen    500 | Evals:   42600 | Best Global: 8.85571 | Current Population: 26.80351 ± 1.256e+01
# Gen   1000 | Evals:   85100 | Best Global: 8.77752 | Current Population: 25.36098 ± 1.296e+01
# Gen   1500 | Evals:  127600 | Best Global: 8.75819 | Current Population: 28.03271 ± 1.302e+01
# Gen   2000 | Evals:  170100 | Best Global: 8.75819 | Current Population: 23.58224 ± 1.119e+01

# %% [markdown]
# Tanto la incializacion diversa (determinista) como la basada en vecinos son mucho mejores que la inicializacion random. No obstante, haber mejorado la inicializacion evidencia que nuestras estrategias de crossover no son eficaces a la hora de pasar de una solucion "suficientemente buena" (la que se instancia al principio) a una "optima".
#
# Creo que es bueno usar estas inicializaciones pero debemos trabajar en estrategias de crossover

# %% [markdown]
# ### Estrategias de crossover

# %%
# PMX crossover

from genetic.factories import *


config = ProblemConfig(max_evaluations=1_000_000, seed=38, output_dir="results/tsp")

# Problem
diverse_ini_problem = TSProblem(config, cities, minimize=True)

# Operators
initialization = initialization_factory("neighbor")
selection = TournamentSelection(1)
crossover = crossover_factory("cycle")
mutation = mutation_factory("swap", mutation_rate = 0.55)
replacement = replacement_factory('mu+lambda')

# Genetic Algorithm
diverse_ini = GeneticAlgorithmSO(
    problem=diverse_ini_problem,
    population_size=3030,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=20
)

res = diverse_ini.run(num_iterations=200)
plot_evolution(
    diverse_ini_problem.mean_history,
    diverse_ini_problem.best_history,
    diverse_ini_problem.worst_history,
)
plot_best(res.best_solution, res.best_fitness)
# Out:
# Gen     20 | Evals:   63630 | Best Global: 41.60220 | Current Population: 50.21230 ± 2.190e+00
# Gen     40 | Evals:  124230 | Best Global: 42.20086 | Current Population: 50.19392 ± 2.113e+00
# Gen     60 | Evals:  184830 | Best Global: 42.42681 | Current Population: 50.25440 ± 2.130e+00
# Gen     80 | Evals:  245430 | Best Global: 43.48014 | Current Population: 50.57577 ± 2.089e+00
# Gen    100 | Evals:  306030 | Best Global: 44.15725 | Current Population: 50.57393 ± 2.070e+00
# Gen    120 | Evals:  366630 | Best Global: 42.99860 | Current Population: 50.71915 ± 2.064e+00
# Gen    140 | Evals:  427230 | Best Global: 42.83071 | Current Population: 50.72537 ± 2.097e+00
# Gen    160 | Evals:  487830 | Best Global: 43.13212 | Current Population: 50.62211 ± 2.112e+00
# Gen    180 | Evals:  548430 | Best Global: 44.07690 | Current Population: 50.74342 ± 2.100e+00
# Gen    200 | Evals:  609030 | Best Global: 42.60716 | Current Population: 50.69069 ± 2.070e+00

# %%
# Cycle crossover

config = ProblemConfig(max_evaluations=1_000_000, seed=38, output_dir="results/tsp")

# Problem
diverse_ini_problem = TSProblem(config, cities, minimize=True)

# Operators
initialization = PermutationInitialization()
selection = TournamentSelection(tournament_size=50)
crossover = CycleCrossover()
mutation = SwapMutation(mutation_rate=1)
replacement = ElitistReplacement(elite_size=15)

# Genetic Algorithm
diverse_ini = GeneticAlgorithmSO(
    problem=diverse_ini_problem,
    population_size=100,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=50
)

res = diverse_ini.run(num_iterations=200)
plot_evolution(
    diverse_ini_problem.mean_history,
    diverse_ini_problem.best_history,
    diverse_ini_problem.worst_history,
)
plot_best(res.best_solution, res.best_fitness)
# Out:
# Gen     50 | Evals:    4350 | Best Global: 24.02008 | Current Population: 24.95534 ± 7.616e-01
# Gen    100 | Evals:    8600 | Best Global: 20.34065 | Current Population: 21.41610 ± 9.336e-01
# Gen    150 | Evals:   12850 | Best Global: 18.09759 | Current Population: 19.29938 ± 8.357e-01
# Gen    200 | Evals:   17100 | Best Global: 16.34759 | Current Population: 17.43852 ± 8.952e-01

# %%
# EdgeRecombinationCrossover crossover

config = ProblemConfig(max_evaluations=1_000_000, seed=38, output_dir="results/tsp")

# Problem
diverse_ini_problem = TSProblem(config, cities, minimize=True)

# Operators
initialization = PermutationInitialization()
selection = TournamentSelection(tournament_size=50)
crossover = EdgeRecombinationCrossover()
mutation = SwapMutation(mutation_rate=1)
replacement = ElitistReplacement(elite_size=15)

# Genetic Algorithm
diverse_ini = GeneticAlgorithmSO(
    problem=diverse_ini_problem,
    population_size=100,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=50
)

res = diverse_ini.run(num_iterations=200)
plot_evolution(
    diverse_ini_problem.mean_history,
    diverse_ini_problem.best_history,
    diverse_ini_problem.worst_history,
)
plot_best(res.best_solution, res.best_fitness)
# Out:
# Gen     50 | Evals:    4350 | Best Global: 17.41963 | Current Population: 18.90049 ± 1.114e+00
# Gen    100 | Evals:    8600 | Best Global: 13.83764 | Current Population: 15.50613 ± 1.188e+00
# Gen    150 | Evals:   12850 | Best Global: 12.17434 | Current Population: 13.96066 ± 1.290e+00
# Gen    200 | Evals:   17100 | Best Global: 11.54835 | Current Population: 12.93794 ± 9.997e-01

# %% [markdown]
# Es cierto que hay mejoras entre cada algoritmo pero todas logran un resultado bastante prometedor: Hacer que el peor caso y el caso promedio se reduzcan a la par que el mejor caso
#
# Ahora faltan probar estrategias de mutaciones

# %% [markdown]
# ### Algoritmos de mutacion
#
# Bamos a usar la ultima configuracion como baseline

# %%
# Inversion mutation

config = ProblemConfig(max_evaluations=1_000_000, seed=38, output_dir="results/tsp")

# Problem
diverse_ini_problem = TSProblem(config, cities, minimize=True)

# Operators
initialization = PermutationInitialization()
selection = TournamentSelection(tournament_size=50)
crossover = EdgeRecombinationCrossover()
mutation = InversionMutation(mutation_rate=1)
replacement = ElitistReplacement(elite_size=15)

# Genetic Algorithm
diverse_ini = GeneticAlgorithmSO(
    problem=diverse_ini_problem,
    population_size=100,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=50
)

res = diverse_ini.run(num_iterations=200)
plot_evolution(
    diverse_ini_problem.mean_history,
    diverse_ini_problem.best_history,
    diverse_ini_problem.worst_history,
)
plot_best(res.best_solution, res.best_fitness)
# Out:
# Gen     50 | Evals:    4350 | Best Global: 17.54729 | Current Population: 18.17572 ± 4.183e-01
# Gen    100 | Evals:    8600 | Best Global: 12.36924 | Current Population: 13.08676 ± 4.654e-01
# Gen    150 | Evals:   12850 | Best Global: 10.46483 | Current Population: 11.22400 ± 5.291e-01
# Gen    200 | Evals:   17100 | Best Global: 9.02400 | Current Population: 9.89442 ± 5.436e-01

# %%
# Otra vez Inversion pero con inicializacion buena y todas las iteraciones posibles
initialization = NeighborInitialization()
mutation = InversionMutation(mutation_rate=1)
diverse_ini = GeneticAlgorithmSO(
    problem=diverse_ini_problem,
    population_size=1000,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=500
)

res = diverse_ini.run()
plot_evolution(
    diverse_ini_problem.mean_history,
    diverse_ini_problem.best_history,
    diverse_ini_problem.worst_history,
)
plot_best(res.best_solution, res.best_fitness)
# Out:
# Gen    500 | Evals:  512585 | Best Global: 7.85697 | Current Population: 8.79826 ± 5.033e-01

# %%
# Scramble Mutation

diverse_ini_problem = TSProblem(config, cities, minimize=True)

# Operators
initialization = PermutationInitialization()
selection = TournamentSelection(tournament_size=50)
crossover = EdgeRecombinationCrossover()
mutation = InversionMutation(mutation_rate=1)
replacement = ElitistReplacement(elite_size=15)

# Genetic Algorithm
diverse_ini = GeneticAlgorithmSO(
    problem=diverse_ini_problem,
    population_size=100,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=50
)

res = diverse_ini.run(num_iterations=200)

diverse_ini.mutation = ScrambleMutation(mutation_rate=1)


res = diverse_ini.run(num_iterations=200)
plot_evolution(
    diverse_ini_problem.mean_history,
    diverse_ini_problem.best_history,
    diverse_ini_problem.worst_history,
)
plot_best(res.best_solution, res.best_fitness)
# Out:
# Gen     50 | Evals:    4350 | Best Global: 17.54729 | Current Population: 18.17572 ± 4.183e-01
# Gen    100 | Evals:    8600 | Best Global: 12.36924 | Current Population: 13.08676 ± 4.654e-01
# Gen    150 | Evals:   12850 | Best Global: 10.46483 | Current Population: 11.22400 ± 5.291e-01
# Gen    200 | Evals:   17100 | Best Global: 9.02400 | Current Population: 9.89442 ± 5.436e-01
# Gen    250 | Evals:   21350 | Best Global: 8.58315 | Current Population: 18.80414 ± 1.157e+01
# Gen    300 | Evals:   25600 | Best Global: 8.44144 | Current Population: 17.81317 ± 1.104e+01
# Gen    350 | Evals:   29850 | Best Global: 8.40786 | Current Population: 19.08757 ± 1.107e+01
# Gen    400 | Evals:   34100 | Best Global: 8.39690 | Current Population: 19.70332 ± 1.147e+01

# %%
# Otra vez Inversion pero con inicializacion buena y muchas iteraciones

diverse_ini_problem = TSProblem(config, cities, minimize=True)
initialization = NeighborInitialization()
mutation = ScrambleMutation(mutation_rate=1)
diverse_ini = GeneticAlgorithmSO(
    problem=diverse_ini_problem,
    population_size=1000,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=100
)

res = diverse_ini.run()
plot_evolution(
    diverse_ini_problem.mean_history,
    diverse_ini_problem.best_history,
    diverse_ini_problem.worst_history,
)
plot_best(res.best_solution, res.best_fitness)
# Out:
# Gen    100 | Evals:   99500 | Best Global: 10.07934 | Current Population: 21.83736 ± 1.002e+01
# Gen    200 | Evals:  198000 | Best Global: 9.70997 | Current Population: 21.26713 ± 1.014e+01
# Gen    300 | Evals:  296500 | Best Global: 9.50671 | Current Population: 20.86299 ± 1.017e+01
# Gen    400 | Evals:  395000 | Best Global: 9.50671 | Current Population: 20.32718 ± 9.944e+00
# Gen    500 | Evals:  493500 | Best Global: 9.50671 | Current Population: 21.06292 ± 1.025e+01
# Gen    600 | Evals:  592000 | Best Global: 9.50671 | Current Population: 21.05724 ± 1.012e+01
# Gen    700 | Evals:  690500 | Best Global: 9.50671 | Current Population: 21.10393 ± 1.024e+01
# Gen    800 | Evals:  789000 | Best Global: 9.50671 | Current Population: 21.68412 ± 1.055e+01
# Gen    900 | Evals:  887500 | Best Global: 9.50671 | Current Population: 20.84419 ± 9.946e+00
# Gen   1000 | Evals:  986000 | Best Global: 9.50671 | Current Population: 20.89911 ± 1.020e+01

# %% [markdown]
# ## Seventh try, basic initialization with improved mutation and crossover

# %%
config = ProblemConfig(max_evaluations=1000000, seed=38, output_dir="results/tsp")

# Problem
problem = TSProblem(config, cities, minimize=True)

# Operators
initialization = PermutationInitialization()
selection = TournamentSelection(tournament_size=50)
crossover = OrderCrossover()
mutation = InversionMutation(mutation_rate=1)
replacement = ElitistReplacement(elite_size=15)

# Genetic Algorithm
ga = GeneticAlgorithmSO(
    problem=problem,
    population_size=100,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=500
)

res = ga.run()

plot_evolution(
    problem.mean_history,
    problem.best_history,
    problem.worst_history,
)

plot_best(res.best_solution, res.best_fitness)
# Out:
# Gen    500 | Evals:   42600 | Best Global: 15.23541 | Current Population: 31.25282 ± 1.206e+01
# Gen   1000 | Evals:   85100 | Best Global: 11.82811 | Current Population: 26.07292 ± 1.246e+01
# Gen   1500 | Evals:  127600 | Best Global: 11.27657 | Current Population: 28.81282 ± 1.337e+01
# Gen   2000 | Evals:  170100 | Best Global: 10.12642 | Current Population: 22.79724 ± 1.204e+01
# Gen   2500 | Evals:  212600 | Best Global: 9.25357 | Current Population: 26.74488 ± 1.497e+01
# Gen   3000 | Evals:  255100 | Best Global: 8.90653 | Current Population: 27.61965 ± 1.552e+01
# Gen   3500 | Evals:  297600 | Best Global: 8.83036 | Current Population: 24.59796 ± 1.285e+01
# Gen   4000 | Evals:  340100 | Best Global: 8.56440 | Current Population: 21.29012 ± 1.231e+01
# Gen   4500 | Evals:  382600 | Best Global: 8.55186 | Current Population: 28.72202 ± 1.540e+01
# Gen   5000 | Evals:  425100 | Best Global: 8.46654 | Current Population: 22.09136 ± 1.249e+01
# ...

# %%
config = ProblemConfig(max_evaluations=1000000, seed=38, output_dir="results/tsp")

# Problem
problem = TSProblem(config, cities, minimize=True)

# Operators
initialization = PermutationInitialization()
selection = TournamentSelection(tournament_size=50)
crossover = EdgeRecombinationCrossover()
mutation = InversionMutation(mutation_rate=1)
replacement = ElitistReplacement(elite_size=15)

# Genetic Algorithm
ga = GeneticAlgorithmSO(
    problem=problem,
    population_size=100,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=500
)

res = ga.run()

plot_evolution(
    problem.mean_history,
    problem.best_history,
    problem.worst_history,
)

plot_best(res.best_solution, res.best_fitness)
# Out:
# Gen    500 | Evals:   42600 | Best Global: 8.23305 | Current Population: 9.00523 ± 5.390e-01
# Gen   1000 | Evals:   85100 | Best Global: 8.23269 | Current Population: 8.90798 ± 4.870e-01
# Gen   1500 | Evals:  127600 | Best Global: 8.23269 | Current Population: 8.99898 ± 4.925e-01
# Gen   2000 | Evals:  170100 | Best Global: 8.23269 | Current Population: 8.96401 ± 5.240e-01
# Gen   2500 | Evals:  212600 | Best Global: 8.23269 | Current Population: 8.98259 ± 5.547e-01
# Gen   3000 | Evals:  255100 | Best Global: 8.23269 | Current Population: 8.93325 ± 5.235e-01
# Gen   3500 | Evals:  297600 | Best Global: 8.23269 | Current Population: 8.91910 ± 4.952e-01
# Gen   4000 | Evals:  340100 | Best Global: 8.23269 | Current Population: 8.94095 ± 5.444e-01
# Gen   4500 | Evals:  382600 | Best Global: 8.23269 | Current Population: 8.98382 ± 5.306e-01
# Gen   5000 | Evals:  425100 | Best Global: 8.23269 | Current Population: 8.90282 ± 5.230e-01
# ...

# %% [markdown]
# ## Genetic + optuna

# %%
from genetic.optuna import OptunaOptimizer
from optuna.samplers import TPESampler
config = ProblemConfig(max_evaluations=1000000, seed=38, output_dir="results/tsp")

# Problem
problem = TSProblem(config, cities, minimize=True)

# Optuna
optuna_trials = 100
startup_trials = int(0.1 * optuna_trials)
sampler = TPESampler(
    n_startup_trials=startup_trials,
    multivariate=True,
    seed=42,
)

optimizer = OptunaOptimizer(problem_config=config,
                            problem=problem,
                            total_trials=optuna_trials,
                            sampler=sampler,
                            max_generations=100,
                            conf_repetitions=2
                            )
# Out:
# /home/adrian/git_repos/practica_biocomp/.venv/lib/python3.13/site-packages/optuna/_experimental.py:32: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# 2026-01-07 02:08:48,539 - OptunaOptimizer - INFO - Inicializando OptunaOptimizer
# [I 2026-01-07 02:08:48,540] A new study created in memory with name: no-name-410f1658-fe35-4ed2-b7a6-727227079143
# 2026-01-07 02:08:48,543 - OptunaOptimizer - INFO - OptunaOptimizer inicializado correctamente

# %%
study = optimizer.run()
# Out:
# 2026-01-07 02:08:48,572 - OptunaOptimizer - INFO - Inicio optimización Optuna (100 trials)
# 2026-01-07 02:08:48,573 - OptunaOptimizer - INFO - Ejecutando ronda: 10 trials (restantes 100)
# /home/adrian/git_repos/practica_biocomp/.venv/lib/python3.13/site-packages/optuna/distributions.py:684: UserWarning: The distribution is specified by [1, 50] and step=2, but the range is not divisible by `step`. It will be replaced with [1, 49].
#   warnings.warn(
# 2026-01-07 02:08:48,579 - OptunaOptimizer - INFO - Evaluando configuración trial=0 | {'population_size': 3110, 'initialization': 'neighbor', 'tournament_size': 29, 'crossover': 'edge_recombination', 'mutation': 'scramble', 'replacement': 'elitist', 'mutation_rate': 0.6000000000000001, 'elite_size': 10}
# ...

# %%
study = optimizer.study

# %%
import joblib

# Guardar el estudio en un archivo
joblib.dump(optimizer.study, "./data/optuna_study_tsp.pkl")

print("Estudio guardado como './data/optuna_study_tsp.pkl'")
# Out:
# Estudio guardado como './data/optuna_study_tsp.pkl'

# %%
import joblib

# Cargar el estudio guardado
study = joblib.load("./data/optuna_study_tsp.pkl")
print(f"Estudio recuperado con {len(study.trials)} trials.")
# Out:
# Estudio recuperado con 78 trials.

# %%
# 2. Forzar el guardado de los registros internos (trazabilidad)
optimizer._flush_records(force=True)

# 3. Ver cuántos trials se completaron realmente
print(f"Trials completados: {len(study.trials)} de {optimizer.total_trials}")

# 4. Obtener el mejor resultado hasta el momento
if len(study.trials) > 0:
    print(f"Mejor avg_loss: {study.best_value:.4f}")
    print(f"Mejores parámetros: {study.best_params}")
else:
    print("No se completó ningún trial aún.")
# Out:
# Trials completados: 78 de 100
# Mejor avg_loss: 7.7048
# Mejores parámetros: {'initialization_name': 'neighbor', 'tournament_size': 43, 'crossover_name': 'edge_recombination', 'mutation_rate': 0.7000000000000001, 'mutation_name': 'inversion', 'replacement_name': 'generational', 'population_size': 8850}

# %%
(optimizer.trials_df)
# Out:
#      trial_number repeat_index     timestamp       loss  \
# 0               0            0  1.767748e+09   8.601602
# 1               0            1  1.767749e+09   8.601602
# 2               0          avg  1.767749e+09   8.601602
# 3               1            0  1.767749e+09  12.065415
# 4               1            1  1.767749e+09  12.065415
# ..            ...          ...           ...        ...
# 152            75            1  1.767809e+09   7.831549
# 153            75          avg  1.767809e+09   7.831549
# 154            76            0  1.767810e+09   7.764432
# 155            76            1  1.767811e+09   7.764432
# 156            76          avg  1.767811e+09   7.764432
#
#                                       genotype_summary  population_size  \
# 0    [31 40 84 72 12 42 35 93 86 74 83 70 33 25 63 ...             3110
# 1    [31 40 84 72 12 42 35 93 86 74 83 70 33 25 63 ...             3110
# 2    [31 40 84 72 12 42 35 93 86 74 83 70 33 25 63 ...             3110
# ...

# %%
df = optimizer.trials_df.copy()
df["repeat_index"] = df["repeat_index"].astype(str)
parquet_path  = "./data/optuna_ga_results.parquet"
df.to_parquet(
    parquet_path,
    index=False,
    engine="fastparquet",
)

# %%
from genetic.optuna import OptunaAnalyzer
# -------------------- Instanciación --------------------
parquet_path = "./data/optuna_ga_results.parquet"
analyzer = OptunaAnalyzer(study=study, parquet_path=parquet_path)

# -------------------- Resumen por trial --------------------
summary = analyzer.summarize_trials()
print("Resumen estadístico por trial:")
print(summary.head())

# -------------------- Top-K trials --------------------
top5 = analyzer.top_k_trials(k=5)
print("\nTop 5 configuraciones (según avg loss):")
print(top5)

# Ordenando por estabilidad (CV)
top5_stable = analyzer.top_k_trials(k=5, sort_by_cv=True)
print("\nTop 5 configuraciones más estables:")
print(top5_stable)

# -------------------- Boxplots automáticos para todas las columnas categóricas --------------------
categorical_cols = ["initialization", "crossover", "mutation", "replacement"]

for cat in categorical_cols:
    print(f"\nBoxplot de loss por {cat}")
    analyzer.plot_box_by_category(cat_col=cat, value_col="loss")

# -------------------- Heatmaps automáticos para todas las combinaciones numéricas --------------------
numeric_cols = ["population_size", "tournament_size", "mutation_rate", "elite_size"]

# Generamos heatmaps para todas las combinaciones posibles (pares)
from itertools import combinations

for x_col, y_col in combinations(numeric_cols, 2):
    print(f"\nHeatmap de loss para {x_col} vs {y_col}")
    analyzer.plot_heatmap_numeric(x_col=x_col, y_col=y_col, value_col="loss")

# -------------------- Comparación estadística top trials --------------------
stat, p_value = analyzer.compare_top_trials(top_n=2, test="mannwhitney")
print(f"\nComparación estadística entre top-2 trials: stat={stat:.3f}, p-value={p_value:.4f}")

# -------------------- Estimación de importancia de hiperparámetros --------------------
importances = analyzer.estimate_param_importance()
print("\nImportancia estimada de los hiperparámetros:")
print(importances)

# -------------------- Análisis de hiperparámetros --------------------
# Esto genera boxplots, scatterplots, heatmaps de interacciones
analyzer.analyze_hyperparams()
# Out:
# Resumen estadístico por trial:
#    trial_number       mean     median  std        min        max  count  \
# 0             0   8.601602   8.601602  0.0   8.601602   8.601602      2
# 1             1  12.065415  12.065415  0.0  12.065415  12.065415      2
# 2             2   7.886280   7.886280  0.0   7.886280   7.886280      2
# 3             3  26.169718  26.169718  0.0  26.169718  26.169718      2
# 4             4   8.715450   8.715450  0.0   8.715450   8.715450      2
#
#    population_size initialization  tournament_size crossover mutation  \
# 0              NaN            NaN              NaN       NaN      NaN
# 1              NaN            NaN              NaN       NaN      NaN
# 2              NaN            NaN              NaN       NaN      NaN
# 3              NaN            NaN              NaN       NaN      NaN
# 4              NaN            NaN              NaN       NaN      NaN
#
#   replacement  elite_size  mutation_rate   cv
# ...

# %% [markdown]
# # ASO

# %%
colony = AntColony(
    nodes=cities,
    ant_count=50,
    alpha=1.0,  # Importancia feromona
    beta=5.0,  # Importancia distancia
    rho=0.1,  # Evaporación
    q0=0.7,  # Explotación
    iterations=40,
    elite_count=3,
    stagnation_limit=10,
    random_state=0,
)
# Out:
# Iteración 1/40: Mejor = 7.77, Actual = 7.77, Promedio = 7.85
# Iteración 2/40: Mejor = 7.70, Actual = 7.70, Promedio = 7.77
# Iteración 3/40: Mejor = 7.70, Actual = 7.70, Promedio = 7.72
# Iteración 4/40: Mejor = 7.65, Actual = 7.65, Promedio = 7.70
# Iteración 5/40: Mejor = 7.65, Actual = 7.65, Promedio = 7.65
# Iteración 6/40: Mejor = 7.65, Actual = 7.65, Promedio = 7.65
# Iteración 7/40: Mejor = 7.65, Actual = 7.65, Promedio = 7.65
# Iteración 8/40: Mejor = 7.65, Actual = 7.65, Promedio = 7.65
# Iteración 9/40: Mejor = 7.65, Actual = 7.65, Promedio = 7.65
# Iteración 10/40: Mejor = 7.65, Actual = 7.65, Promedio = 7.65
# Iteración 11/40: Mejor = 7.65, Actual = 7.65, Promedio = 7.65
# Iteración 12/40: Mejor = 7.65, Actual = 7.65, Promedio = 7.65
# Iteración 13/40: Mejor = 7.65, Actual = 7.65, Promedio = 7.65
# Iteración 14/40: Mejor = 7.65, Actual = 7.65, Promedio = 7.65
# Iteración 15/40: Mejor = 7.65, Actual = 7.65, Promedio = 7.65
# ...

# %%
# La mejor solución encontrada hasta ahora fue 7.59 (sin semilla, así que ahora mismo no lo podemos replicar)
fig, ax = create_figure()
plot_nodes(ax, cities)
optimal_path = colony.get_path()
plot_path(ax, optimal_path)
print(optimal_path)
# Out:
# ...
# Distancia óptima encontrada: 7.65
# Mejora desde inicio: 0.12
# Mejora porcentual: 1.5%
# ...
