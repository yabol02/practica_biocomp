# %%
cd ..
# Out:
# c:\Users\rahar\Desktop\master\BIOCOMP\backup\practica_biocomp

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from genetic.algorithms import GeneticAlgorithmMO
from genetic.configurations import ProblemConfig
from genetic.crossover import BlendCrossover
from genetic.initialization import RandomInitialization
from genetic.mutation import UniformMutation
from genetic.problems import PymooProblem
from genetic.replacement import GenerationalReplacement
from genetic.selection import ParetoSelection

# %% [markdown]
# # First try

# %%
config = ProblemConfig(max_evaluations=10000, seed=42, output_dir="results/zdt1")

# Problem
name = "mw7"
problem = PymooProblem(config, name, n_var=30)

# Operators
initialization = RandomInitialization()
selection = ParetoSelection()
crossover = BlendCrossover(alpha=0.5)
mutation = UniformMutation(mutation_rate=0.15, bounds=problem.get_bounds())
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
)

# %%
print("=" * 80)
print("OPTIMIZING MW7 FUNCTIONS")
print("=" * 80)
result = ga.run()
# Out:
# ================================================================================
# OPTIMIZING MW7 FUNCTIONS
# ================================================================================
# Gen 0: Evals=50/10000, Pareto size=5, Sample objectives=['13.1198', '15.7753']
# Gen 10: Evals=550/10000, Pareto size=7, Sample objectives=['4.8400', '6.5806']
# Gen 20: Evals=1050/10000, Pareto size=11, Sample objectives=['2.3927', '13.1407']
# Gen 30: Evals=1550/10000, Pareto size=9, Sample objectives=['8.6324', '1.9267']
# Gen 40: Evals=2050/10000, Pareto size=8, Sample objectives=['0.0000', '11.1896']
# Gen 50: Evals=2550/10000, Pareto size=9, Sample objectives=['9.4591', '0.0000']
# Gen 60: Evals=3050/10000, Pareto size=10, Sample objectives=['2.7531', '8.7409']
# Gen 70: Evals=3550/10000, Pareto size=10, Sample objectives=['7.8796', '3.9098']
# Gen 80: Evals=4050/10000, Pareto size=10, Sample objectives=['0.9713', '8.4442']
# Gen 90: Evals=4550/10000, Pareto size=10, Sample objectives=['8.1090', '4.6390']
# Gen 100: Evals=5050/10000, Pareto size=10, Sample objectives=['2.2958', '13.2830']
# Gen 110: Evals=5550/10000, Pareto size=10, Sample objectives=['7.0742', '0.0000']
# Gen 120: Evals=6050/10000, Pareto size=10, Sample objectives=['4.0430', '7.7887']
# Gen 130: Evals=6550/10000, Pareto size=10, Sample objectives=['7.6142', '4.3858']
# Gen 140: Evals=7050/10000, Pareto size=10, Sample objectives=['8.0045', '5.4468']
# Gen 150: Evals=7550/10000, Pareto size=10, Sample objectives=['6.5923', '9.3352']
# Gen 160: Evals=8050/10000, Pareto size=10, Sample objectives=['1.4816', '13.2186']
# Gen 170: Evals=8550/10000, Pareto size=10, Sample objectives=['7.5488', '0.0000']
# Gen 180: Evals=9050/10000, Pareto size=10, Sample objectives=['9.2296', '0.0000']
# Gen 190: Evals=9550/10000, Pareto size=10, Sample objectives=['0.0000', '9.6919']

# %%
print("\n" + "=" * 40)
print("RESULTS")
print("=" * 40)
print(f"Problem: {result.problem_name}")
print(f"Evaluations used: {result.evaluations_used}")
print(f"Generations: {len(result.history)}")
print(f"Metrics:")
for metric, value in result.metrics.items():
    print(f"  - {metric}: {value}")
# Out:
# ========================================
# RESULTS
# ========================================
# Problem: PymooProblem
# Evaluations used: 10000
# Generations: 0
# Metrics:
#   - n_pareto_solutions: 10
#   - pareto_spread: 1.6745949947005585
#   - history_length: 201

# %%
front = problem.plot_pareto_front(True)
front.show()

# %% [markdown]
# # Second try, optimizing hyperparameters

# %%
def print_result(result):
    print("\n" + "=" * 40)
    print("RESULTS")
    print("=" * 40)
    print(f"Problem: {result.problem_name}")
    print(f"Evaluations used: {result.evaluations_used}")
    print(f"Generations: {len(result.history)}")
    print(f"Metrics:")
    for metric, value in result.metrics.items():
        print(f"  - {metric}: {value}")

# %%
config = ProblemConfig(max_evaluations=10000, seed=42, output_dir="results/zdt1")

# Problem
name = "mw7"
problem = PymooProblem(config, name, n_var=30)

# Operators
initialization = RandomInitialization()
selection = ParetoSelection()
crossover = BlendCrossover(alpha=0.33)
mutation = UniformMutation(mutation_rate=0.034, bounds=problem.get_bounds())
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
)

result = ga.run()

print_result(result)

front = problem.plot_pareto_front(True)
front.show()
# Out:
# Gen 0: Evals=50/10000, Pareto size=5, Sample objectives=['13.1198', '15.7753']
# Gen 10: Evals=550/10000, Pareto size=9, Sample objectives=['3.1841', '6.6388']
# Gen 20: Evals=1050/10000, Pareto size=8, Sample objectives=['4.2233', '3.8464']
# Gen 30: Evals=1550/10000, Pareto size=16, Sample objectives=['1.7621', '2.6622']
# Gen 40: Evals=2050/10000, Pareto size=11, Sample objectives=['1.0652', '4.0790']
# Gen 50: Evals=2550/10000, Pareto size=11, Sample objectives=['4.7245', '0.0000']
# Gen 60: Evals=3050/10000, Pareto size=14, Sample objectives=['0.7052', '2.2390']
# Gen 70: Evals=3550/10000, Pareto size=12, Sample objectives=['0.3390', '1.5320']
# Gen 80: Evals=4050/10000, Pareto size=13, Sample objectives=['0.2684', '2.4346']
# Gen 90: Evals=4550/10000, Pareto size=14, Sample objectives=['0.5481', '1.6365']
# Gen 100: Evals=5050/10000, Pareto size=16, Sample objectives=['0.4116', '2.1698']
# Gen 110: Evals=5550/10000, Pareto size=17, Sample objectives=['1.6028', '0.7703']
# Gen 120: Evals=6050/10000, Pareto size=17, Sample objectives=['0.9798', '1.3474']
# Gen 130: Evals=6550/10000, Pareto size=17, Sample objectives=['1.4304', '0.7145']
# Gen 140: Evals=7050/10000, Pareto size=15, Sample objectives=['0.0000', '3.0868']
# Gen 150: Evals=7550/10000, Pareto size=14, Sample objectives=['1.0388', '1.5662']
# Gen 160: Evals=8050/10000, Pareto size=13, Sample objectives=['1.2571', '2.6961']
# Gen 170: Evals=8550/10000, Pareto size=14, Sample objectives=['1.9910', '0.1889']
# Gen 180: Evals=9050/10000, Pareto size=16, Sample objectives=['1.8284', '2.5681']
# Gen 190: Evals=9550/10000, Pareto size=14, Sample objectives=['0.0000', '2.1071']
#
# ========================================
# RESULTS
# ========================================
# Problem: PymooProblem
# Evaluations used: 10000
# Generations: 0
# Metrics:
#   - n_pareto_solutions: 17
#   - pareto_spread: 0.10659272185772649
#   - history_length: 201

# %% [markdown]
# # Cosas raras

# %%
config = ProblemConfig(max_evaluations=10000, seed=42, output_dir="results/zdt1")

# Problem
name = "mw7"
problem = PymooProblem(config, name, n_var=30)

# Operators
initialization = RandomInitialization()
selection = ParetoSelection()
crossover = BlendCrossover(alpha=0.5)
mutation = UniformMutation(mutation_rate=0.01, bounds=problem.get_bounds())
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
)

result = ga.run()

print_result(result)

front = problem.plot_pareto_front(True)
front.show()
# Out:
# Gen 0: Evals=50/10000, Pareto size=5, Sample objectives=['13.1198', '15.7753']
# Gen 10: Evals=550/10000, Pareto size=9, Sample objectives=['4.9154', '5.3110']
# Gen 20: Evals=1050/10000, Pareto size=5, Sample objectives=['3.9310', '1.0943']
# Gen 30: Evals=1550/10000, Pareto size=8, Sample objectives=['0.9771', '2.4744']
# Gen 40: Evals=2050/10000, Pareto size=15, Sample objectives=['0.0000', '2.4730']
# Gen 50: Evals=2550/10000, Pareto size=22, Sample objectives=['1.2310', '0.0000']
# Gen 60: Evals=3050/10000, Pareto size=37, Sample objectives=['0.0000', '1.2074']
# Gen 70: Evals=3550/10000, Pareto size=52, Sample objectives=['1.2685', '0.1339']
# Gen 80: Evals=4050/10000, Pareto size=65, Sample objectives=['0.5034', '0.9800']
# Gen 90: Evals=4550/10000, Pareto size=68, Sample objectives=['1.0603', '0.6148']
# Gen 100: Evals=5050/10000, Pareto size=75, Sample objectives=['0.5917', '0.9705']
# Gen 110: Evals=5550/10000, Pareto size=93, Sample objectives=['1.0151', '0.4861']
# Gen 120: Evals=6050/10000, Pareto size=108, Sample objectives=['0.4282', '1.0097']
# Gen 130: Evals=6550/10000, Pareto size=120, Sample objectives=['0.5399', '0.9190']
# Gen 140: Evals=7050/10000, Pareto size=128, Sample objectives=['0.4549', '1.6064']
# Gen 150: Evals=7550/10000, Pareto size=160, Sample objectives=['0.8812', '0.5967']
# Gen 160: Evals=8050/10000, Pareto size=153, Sample objectives=['0.3143', '1.0209']
# Gen 170: Evals=8550/10000, Pareto size=168, Sample objectives=['1.1196', '0.0000']
# Gen 180: Evals=9050/10000, Pareto size=157, Sample objectives=['1.6183', '2.0301']
# Gen 190: Evals=9550/10000, Pareto size=159, Sample objectives=['0.1151', '1.0522']
#
# ========================================
# RESULTS
# ========================================
# Problem: PymooProblem
# Evaluations used: 10000
# Generations: 0
# Metrics:
#   - n_pareto_solutions: 168
#   - pareto_spread: 0.0604489304584278
#   - history_length: 201

# %%
result.best_solution[4]
# Out:
# array([0.52280793, 0.95186993, 0.82422418, 0.88247223, 0.84951623,
#        0.89255915, 0.86229538, 0.83829108, 0.8758901 , 0.84596681,
#        0.88348251, 0.82810548, 0.88944594, 0.85254915, 0.82381716,
#        0.97603116, 0.72581975, 0.93056714, 0.82291909, 0.8691955 ,
#        0.87174656, 0.88363521, 0.84976784, 0.90439408, 0.84119588,
#        0.86951729, 0.84303289, 0.90345195, 0.83533713, 0.88563279])
