# %%
cd ..
# Out:
# c:\Users\rahar\Desktop\master\BIOCOMP\backup\practica_biocomp

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from genetic.algorithms import GeneticAlgorithmMO
from genetic.configurations import ProblemConfig
from genetic.crossover import BlendCrossover
from genetic.initialization import RandomInitialization
from genetic.mutation import UniformMutation
from genetic.problems import PymooProblemConstraints
from genetic.replacement import GenerationalReplacement
from genetic.selection import ParetoSelection

# %% [markdown]
# # First try
#
# Sale fatal, es normal. Las restricciones añaden penelizaciones de 1e6 por cada violación.

# %%
config = ProblemConfig(max_evaluations=10000, seed=42, output_dir="results/zdt1")

# Problem
name = "mw7"
problem = PymooProblemConstraints(config, name, n_var=30)

# Operators
initialization = RandomInitialization()
selection = ParetoSelection()
crossover = BlendCrossover(alpha=0.5)
mutation = UniformMutation(mutation_rate=0.15, bounds=problem.get_bounds())
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
)

# %%
print("=" * 80)
print("OPTIMIZING MW7 FUNCTIONS")
print("=" * 80)
result = ga.run()
# Out:
# ================================================================================
# OPTIMIZING MW7 FUNCTIONS
# ================================================================================
# Gen 0: Evals=50/10000, Pareto size=1, Sample objectives=['133509141.8462', '133509143.3497']
# Gen 10: Evals=550/10000, Pareto size=1, Sample objectives=['3790379.4217', '3790378.4794']
# Gen 20: Evals=1050/10000, Pareto size=1, Sample objectives=['17186127.9781', '17186123.6623']
# Gen 30: Evals=1550/10000, Pareto size=1, Sample objectives=['13839271.9512', '13839275.2247']
# Gen 40: Evals=2050/10000, Pareto size=2, Sample objectives=['9171747.3772', '9171748.3580']
# Gen 50: Evals=2550/10000, Pareto size=3, Sample objectives=['6661322.0704', '6661320.0678']
# Gen 60: Evals=3050/10000, Pareto size=3, Sample objectives=['7560059.2284', '7560058.4779']
# Gen 70: Evals=3550/10000, Pareto size=3, Sample objectives=['10740151.9354', '10740151.0676']
# Gen 80: Evals=4050/10000, Pareto size=3, Sample objectives=['6602030.6118', '6602032.6342']
# Gen 90: Evals=4550/10000, Pareto size=3, Sample objectives=['34747558.2534', '34747556.6774']
# Gen 100: Evals=5050/10000, Pareto size=3, Sample objectives=['5524639.3985', '5524641.2950']
# Gen 110: Evals=5550/10000, Pareto size=3, Sample objectives=['30713404.8950', '30713409.8746']
# Gen 120: Evals=6050/10000, Pareto size=3, Sample objectives=['3570062.4204', '3570063.4365']
# Gen 130: Evals=6550/10000, Pareto size=3, Sample objectives=['9437405.7355', '9437406.4036']
# Gen 140: Evals=7050/10000, Pareto size=3, Sample objectives=['40896041.3771', '40896040.9863']
# Gen 150: Evals=7550/10000, Pareto size=3, Sample objectives=['23326748.4141', '23326750.6463']
# Gen 160: Evals=8050/10000, Pareto size=3, Sample objectives=['5108584.6649', '5108586.4632']
# Gen 170: Evals=8550/10000, Pareto size=3, Sample objectives=['9757283.7808', '9757286.6699']
# Gen 180: Evals=9050/10000, Pareto size=3, Sample objectives=['6047909.1801', '6047909.0734']
# Gen 190: Evals=9550/10000, Pareto size=4, Sample objectives=['4340040.4203', '4340042.0170']

# %%
print("\n" + "=" * 40)
print("RESULTS")
print("=" * 40)
print(f"Problem: {result.problem_name}")
print(f"Evaluations used: {result.evaluations_used}")
print(f"Generations: {len(result.history)}")
print(f"Metrics:")
for metric, value in result.metrics.items():
    print(f"  - {metric}: {value}")
# Out:
# ========================================
# RESULTS
# ========================================
# Problem: PymooProblemConstraints
# Evaluations used: 10000
# Generations: 0
# Metrics:
#   - n_pareto_solutions: 12
#   - pareto_spread: 0.18198064416302762
#   - history_length: 201

# %%
front = problem.plot_pareto_front(True)
front.show()

# %% [markdown]
# # Second try, optimizing hyperparameters

# %%
def print_result(result):
    print("\n" + "=" * 40)
    print("RESULTS")
    print("=" * 40)
    print(f"Problem: {result.problem_name}")
    print(f"Evaluations used: {result.evaluations_used}")
    print(f"Generations: {len(result.history)}")
    print(f"Metrics:")
    for metric, value in result.metrics.items():
        print(f"  - {metric}: {value}")

# %%
config = ProblemConfig(max_evaluations=10000, seed=42, output_dir="results/zdt1")

# Problem
name = "mw7"
problem = PymooProblemConstraints(config, name, n_var=30)

# Operators
initialization = RandomInitialization()
selection = ParetoSelection()
crossover = BlendCrossover(alpha=0.5)
mutation = UniformMutation(mutation_rate=0.01, bounds=problem.get_bounds())
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
)

result = ga.run()

print_result(result)

front = problem.plot_pareto_front(True)
front.show()
# Out:
# Gen 0: Evals=50/10000, Pareto size=1, Sample objectives=['133509141.8462', '133509143.3497']
# Gen 10: Evals=550/10000, Pareto size=1, Sample objectives=['3250621.9442', '3250619.7784']
# Gen 20: Evals=1050/10000, Pareto size=10, Sample objectives=['25894.5576', '25893.7809']
# Gen 30: Evals=1550/10000, Pareto size=24, Sample objectives=['5323218.0288', '5323216.6795']
# Gen 40: Evals=2050/10000, Pareto size=33, Sample objectives=['1899.7974', '1899.1359']
# Gen 50: Evals=2550/10000, Pareto size=40, Sample objectives=['0.9275', '0.4047']
# Gen 60: Evals=3050/10000, Pareto size=64, Sample objectives=['0.9545', '0.3241']
# Gen 70: Evals=3550/10000, Pareto size=86, Sample objectives=['0.9291', '0.3866']
# Gen 80: Evals=4050/10000, Pareto size=174, Sample objectives=['0.9253', '0.3871']
# Gen 90: Evals=4550/10000, Pareto size=237, Sample objectives=['0.9252', '0.3887']
# Gen 100: Evals=5050/10000, Pareto size=260, Sample objectives=['0.9085', '0.4272']
# Gen 110: Evals=5550/10000, Pareto size=288, Sample objectives=['1512754.8562', '1512753.8030']
# Gen 120: Evals=6050/10000, Pareto size=305, Sample objectives=['0.9287', '0.3793']
# Gen 130: Evals=6550/10000, Pareto size=335, Sample objectives=['0.9324', '0.3697']
# Gen 140: Evals=7050/10000, Pareto size=360, Sample objectives=['0.9294', '0.3761']
# Gen 150: Evals=7550/10000, Pareto size=346, Sample objectives=['0.9426', '0.3417']
# Gen 160: Evals=8050/10000, Pareto size=322, Sample objectives=['0.9247', '0.3926']
# Gen 170: Evals=8550/10000, Pareto size=361, Sample objectives=['0.9184', '0.4019']
# Gen 180: Evals=9050/10000, Pareto size=412, Sample objectives=['0.9408', '0.3972']
# Gen 190: Evals=9550/10000, Pareto size=462, Sample objectives=['1565.9054', '1565.4552']
#
# ========================================
# RESULTS
# ========================================
# Problem: PymooProblemConstraints
# Evaluations used: 10000
# Generations: 0
# Metrics:
#   - n_pareto_solutions: 570
#   - pareto_spread: 0.02159155405506795
#   - history_length: 201

# %% [markdown]
# ## Third try, adjust

# %%
config = ProblemConfig(max_evaluations=10000, seed=42, output_dir="results/zdt1")

# Problem
name = "mw7"
problem = PymooProblemConstraints(config, name, n_var=30)

# Operators
initialization = RandomInitialization()
selection = ParetoSelection()
crossover = BlendCrossover(alpha=0.5)
mutation = UniformMutation(mutation_rate=0.001, bounds=problem.get_bounds())
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
)

result = ga.run()

print_result(result)

front = problem.plot_pareto_front(True)
front.show()
# Out:
# Gen 0: Evals=50/10000, Pareto size=1, Sample objectives=['133509141.8462', '133509143.3497']
# Gen 10: Evals=550/10000, Pareto size=2, Sample objectives=['752060.6019', '752061.3266']
# Gen 20: Evals=1050/10000, Pareto size=18, Sample objectives=['0.4970', '1.0554']
# Gen 30: Evals=1550/10000, Pareto size=33, Sample objectives=['20577.7480', '20578.5019']
# Gen 40: Evals=2050/10000, Pareto size=54, Sample objectives=['0.3927', '0.9563']
# Gen 50: Evals=2550/10000, Pareto size=61, Sample objectives=['0.4026', '0.9336']
# Gen 60: Evals=3050/10000, Pareto size=78, Sample objectives=['0.3816', '0.9386']
# Gen 70: Evals=3550/10000, Pareto size=106, Sample objectives=['0.3855', '0.9307']
# Gen 80: Evals=4050/10000, Pareto size=148, Sample objectives=['0.3933', '0.9260']
# Gen 90: Evals=4550/10000, Pareto size=143, Sample objectives=['0.3900', '0.9269']
# Gen 100: Evals=5050/10000, Pareto size=199, Sample objectives=['0.4101', '0.9168']
# Gen 110: Evals=5550/10000, Pareto size=251, Sample objectives=['0.3891', '0.9253']
# Gen 120: Evals=6050/10000, Pareto size=243, Sample objectives=['0.4030', '0.9190']
# Gen 130: Evals=6550/10000, Pareto size=307, Sample objectives=['0.3946', '0.9221']
# Gen 140: Evals=7050/10000, Pareto size=334, Sample objectives=['0.3953', '0.9221']
# Gen 150: Evals=7550/10000, Pareto size=386, Sample objectives=['0.3951', '0.9220']
# Gen 160: Evals=8050/10000, Pareto size=437, Sample objectives=['0.3872', '0.9249']
# Gen 170: Evals=8550/10000, Pareto size=507, Sample objectives=['0.4030', '0.9182']
# Gen 180: Evals=9050/10000, Pareto size=572, Sample objectives=['0.4141', '0.9136']
# Gen 190: Evals=9550/10000, Pareto size=593, Sample objectives=['0.4027', '0.9183']
#
# ========================================
# RESULTS
# ========================================
# Problem: PymooProblemConstraints
# Evaluations used: 10000
# Generations: 0
# Metrics:
#   - n_pareto_solutions: 597
#   - pareto_spread: 0.00483075611790065
#   - history_length: 201

# %%
config = ProblemConfig(max_evaluations=10000, seed=42, output_dir="results/zdt1")

# Problem
name = "mw7"
problem = PymooProblemConstraints(config, name, n_var=30)

# Operators
initialization = RandomInitialization()
selection = ParetoSelection()
crossover = BlendCrossover(alpha=0.5)
mutation = UniformMutation(mutation_rate=0.005, bounds=problem.get_bounds())
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
)

result = ga.run()

print_result(result)

front = problem.plot_pareto_front(True)
front.show()
# Out:
# Gen 0: Evals=50/10000, Pareto size=1, Sample objectives=['419548768.0278', '419548770.6833']
# Gen 10: Evals=550/10000, Pareto size=1, Sample objectives=['20132679.6688', '20132682.6558']
# Gen 20: Evals=1050/10000, Pareto size=1, Sample objectives=['10657845.3852', '10657841.9070']
# Gen 30: Evals=1550/10000, Pareto size=8, Sample objectives=['48386.6502', '48385.8699']
# Gen 40: Evals=2050/10000, Pareto size=8, Sample objectives=['1.1563', '0.4877']
# Gen 50: Evals=2550/10000, Pareto size=15, Sample objectives=['1.1079', '0.3164']
# Gen 60: Evals=3050/10000, Pareto size=36, Sample objectives=['1.0778', '0.3340']
# Gen 70: Evals=3550/10000, Pareto size=81, Sample objectives=['42491.5917', '42491.3184']
# Gen 80: Evals=4050/10000, Pareto size=96, Sample objectives=['0.5939', '0.9848']
# Gen 90: Evals=4550/10000, Pareto size=117, Sample objectives=['181831.4786', '181831.5669']
# Gen 100: Evals=5050/10000, Pareto size=124, Sample objectives=['37712.9200', '37713.9797']
# Gen 110: Evals=5550/10000, Pareto size=122, Sample objectives=['1.0280', '0.4931']
# Gen 120: Evals=6050/10000, Pareto size=132, Sample objectives=['0.6628', '0.9883']
# Gen 130: Evals=6550/10000, Pareto size=136, Sample objectives=['0.3786', '1.0241']
# Gen 140: Evals=7050/10000, Pareto size=145, Sample objectives=['0.3737', '1.0578']
# Gen 150: Evals=7550/10000, Pareto size=148, Sample objectives=['0.4810', '0.9932']
# Gen 160: Evals=8050/10000, Pareto size=151, Sample objectives=['0.3654', '1.0275']
# Gen 170: Evals=8550/10000, Pareto size=158, Sample objectives=['0.5343', '0.9421']
# Gen 180: Evals=9050/10000, Pareto size=165, Sample objectives=['5162747.7298', '5162748.6527']
# Gen 190: Evals=9550/10000, Pareto size=183, Sample objectives=['0.4367', '0.9721']
#
# ========================================
# RESULTS
# ========================================
# Problem: PymooProblem
# Evaluations used: 10000
# Generations: 0
# Metrics:
#   - n_pareto_solutions: 176
#   - pareto_spread: 0.09189020824814517
#   - history_length: 201

# %% [markdown]
# # NSGA-II

# %%
res2 = problem.get_nsga2_result()
front2 = problem.plot_pareto_front(True)
front2.show()
