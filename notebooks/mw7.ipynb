# %%
cd ..
# Out:
# c:\Users\Yago\Desktop\MAADM\3 Computación Evolutiva y Bioinspirada\practica_biocomp

# %%
from genetic.algorithms import GeneticAlgorithmMO
from genetic.configurations import ProblemConfig
from genetic.crossover import BlendCrossover
from genetic.initialization import RandomInitialization
from genetic.mutation import UniformMutation
from genetic.problems import PymooProblem
from genetic.replacement import GenerationalReplacement
from genetic.selection import ParetoSelection

# %%
config = ProblemConfig(max_evaluations=10000, seed=42, output_dir="results/zdt1")

# Problem
name = "mw7"
problem = PymooProblem(config, name, n_var=30)

# Operators
initialization = RandomInitialization()
selection = ParetoSelection()
crossover = BlendCrossover(alpha=0.5)
mutation = UniformMutation(mutation_rate=0.15, bounds=problem.get_bounds())
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
)

# %%
print("=" * 80)
print("OPTIMIZING ZDT1 FUNCTIONS")
print("=" * 80)
result = ga.run()
# Out:
# ================================================================================
# OPTIMIZING ZDT1 FUNCTIONS
# ================================================================================
# Gen 0: Evals=50/10000, Pareto size=5, Sample objectives=['13.1198', '15.7753']
# Gen 10: Evals=550/10000, Pareto size=18, Sample objectives=['7.4147', '14.3960']
# Gen 20: Evals=1050/10000, Pareto size=17, Sample objectives=['10.5052', '7.2716']
# Gen 30: Evals=1550/10000, Pareto size=20, Sample objectives=['3.7984', '11.2049']
# Gen 40: Evals=2050/10000, Pareto size=15, Sample objectives=['1.0929', '11.6698']
# Gen 50: Evals=2550/10000, Pareto size=13, Sample objectives=['9.1341', '4.9434']
# Gen 60: Evals=3050/10000, Pareto size=12, Sample objectives=['3.7832', '12.0115']
# Gen 70: Evals=3550/10000, Pareto size=11, Sample objectives=['5.2727', '8.4141']
# Gen 80: Evals=4050/10000, Pareto size=11, Sample objectives=['3.8572', '13.4385']
# Gen 90: Evals=4550/10000, Pareto size=11, Sample objectives=['8.3233', '4.7616']
# Gen 100: Evals=5050/10000, Pareto size=12, Sample objectives=['13.0660', '9.6548']
# Gen 110: Evals=5550/10000, Pareto size=12, Sample objectives=['8.9532', '3.2349']
# Gen 120: Evals=6050/10000, Pareto size=12, Sample objectives=['11.0311', '3.0716']
# Gen 130: Evals=6550/10000, Pareto size=13, Sample objectives=['6.0279', '8.6771']
# Gen 140: Evals=7050/10000, Pareto size=14, Sample objectives=['1.9008', '15.3632']
# Gen 150: Evals=7550/10000, Pareto size=14, Sample objectives=['9.2414', '7.5747']
# Gen 160: Evals=8050/10000, Pareto size=14, Sample objectives=['7.3607', '9.1875']
# Gen 170: Evals=8550/10000, Pareto size=15, Sample objectives=['11.9766', '2.3217']
# Gen 180: Evals=9050/10000, Pareto size=16, Sample objectives=['4.5986', '9.4066']
# Gen 190: Evals=9550/10000, Pareto size=16, Sample objectives=['7.0135', '10.2126']

# %%
print("\n" + "=" * 40)
print("RESULTS")
print("=" * 40)
print(f"Problem: {result.problem_name}")
print(f"Evaluations used: {result.evaluations_used}")
print(f"Generations: {len(result.history)}")
print(f"Metrics:")
for metric, value in result.metrics.items():
    print(f"  - {metric}: {value}")
# Out:
# ========================================
# RESULTS
# ========================================
# Problem: PymooProblem
# Evaluations used: 10000
# Generations: 0
# Metrics:
#   - n_pareto_solutions: 16
#   - pareto_spread: 10.232835492915424
#   - history_length: 201

# %%
front = problem.plot_pareto_front(True)
front.show()
