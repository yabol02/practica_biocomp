    (0.387141492676661, 0.5792852545912592),
    (0.8634070619751958, 0.8206820685065667),
    (0.4662474858565825, 0.32647667516764145),
    (0.01801973379815025, 0.12175434785651695),
    (0.6218125565554127, 0.07860046445444713),
    (0.6573938922925594, 0.5023092428939168),
    (0.2837581848186974, 0.02576704782244421),
    (0.3044774374252185, 0.7310313422019327),
    (0.33131673439274434, 0.693896434962478),
    (0.8523694048117944, 0.2805224723356823),
    (0.6200019812032047, 0.03989814578273998),
    (0.5437394088109648, 0.3258031129949792),
    (0.4386079860370994, 0.6142798815693052),
    (0.7430581106897977, 0.49260737229959284),
    (0.3913628378102181, 0.3185830750836698),
    (0.9065498976196814, 0.02381958527497441),
    (0.6874236611131453, 0.18642068590773597),
    (0.6946411585627993, 0.36991609629423117),
    (0.3784063098306413, 0.01018756575849844),
    (0.43806374889930155, 0.2268325586117821),
    (0.7411632641820634, 0.35513151640087337),
    (0.3884706603234591, 0.34043302784114093),
    (0.08674110453583683, 0.4491174987265194),
    (0.9794883193315694, 0.11207520940235804),
    (0.7496156619797683, 0.23845386610980834),
    (0.4423888847621813, 0.17212722421686055),
    (0.2276570035864689, 0.6515924491551327),
    (0.836939257954547, 0.0499933914625984),
)

# %%
import random

import matplotlib.pyplot as plt
import numpy as np

from genetic.algorithms import GeneticAlgorithmSO
from genetic.configurations import ProblemConfig
from genetic.crossover import OrderCrossover
from genetic.initialization import PermutationInitialization
from genetic.mutation import SwapMutation
from genetic.problems import TSProblem
from genetic.replacement import GenerationalReplacement
from genetic.selection import TournamentSelection

# %%
plt.style.use("dark_background")
random.seed(42)
np.random.seed(42)


def create_figure(w=12, h=8):
    fig, ax = plt.subplots(figsize=(w, h))
    ax.axis("off")
    return fig, ax


def plot_nodes(ax, nodes, color="r", size=5):
    for x, y in nodes:
        ax.plot(x, y, ".", color=color, markersize=size)


def plot_path(ax, path, color="b", linewidth=1.5):
    for i in range(len(path) - 1):
        x = (path[i][0], path[i + 1][0])
        y = (path[i][1], path[i + 1][1])
        ax.plot(x, y, color=color, linewidth=linewidth)

# %%
config = ProblemConfig(max_evaluations=1000000, seed=42, output_dir="results/tsp")

# Problem
problem = TSProblem(config, cities)

# Operators
initialization = PermutationInitialization()
selection = TournamentSelection(tournament_size=3)
crossover = OrderCrossover()
mutation = SwapMutation(mutation_rate=0.15)
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmSO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
    print_interval=1000,
)

# %%
print("=" * 80)
print("OPTIMIZING TRAVELING SALESMAN PROBLEM")
print("=" * 80)
result = ga.run()
# Out:
# ================================================================================
# OPTIMIZING TRAVELING SALESMAN PROBLEM
# ================================================================================
# Gen   1000 | Evals:   50050 | Best Global: 33.69736 | Current Population: 39.21288 ± 5.231e+00
# Gen   2000 | Evals:  100050 | Best Global: 33.31351 | Current Population: 38.07120 ± 5.350e+00
# Gen   3000 | Evals:  150050 | Best Global: 31.71893 | Current Population: 36.12161 ± 5.139e+00
# Gen   4000 | Evals:  200050 | Best Global: 29.09407 | Current Population: 35.60599 ± 6.852e+00
# Gen   5000 | Evals:  250050 | Best Global: 28.93525 | Current Population: 35.69418 ± 7.756e+00
# Gen   6000 | Evals:  300050 | Best Global: 29.35524 | Current Population: 37.48565 ± 7.656e+00
# Gen   7000 | Evals:  350050 | Best Global: 30.98063 | Current Population: 38.13337 ± 5.096e+00
# Gen   8000 | Evals:  400050 | Best Global: 27.55857 | Current Population: 37.15967 ± 7.929e+00
# Gen   9000 | Evals:  450050 | Best Global: 27.42779 | Current Population: 32.67698 ± 7.074e+00
# Gen  10000 | Evals:  500050 | Best Global: 25.75709 | Current Population: 34.00460 ± 7.174e+00
# Gen  11000 | Evals:  550050 | Best Global: 25.70735 | Current Population: 35.29143 ± 8.483e+00
# Gen  12000 | Evals:  600050 | Best Global: 26.42251 | Current Population: 32.69211 ± 7.159e+00
# Gen  13000 | Evals:  650050 | Best Global: 27.55140 | Current Population: 35.46356 ± 9.078e+00
# Gen  14000 | Evals:  700050 | Best Global: 28.10735 | Current Population: 36.69602 ± 8.173e+00
# Gen  15000 | Evals:  750050 | Best Global: 27.54406 | Current Population: 35.40511 ± 6.937e+00
# Gen  16000 | Evals:  800050 | Best Global: 26.91810 | Current Population: 37.38798 ± 8.707e+00
# Gen  17000 | Evals:  850050 | Best Global: 29.42896 | Current Population: 36.17240 ± 7.873e+00
# Gen  18000 | Evals:  900050 | Best Global: 27.98512 | Current Population: 35.66032 ± 7.219e+00
# Gen  19000 | Evals:  950050 | Best Global: 27.31583 | Current Population: 35.12059 ± 8.476e+00

# %%
print("\n" + "=" * 40)
print("RESULTS")
print("=" * 40)
print(f"Problem: {result.problem_name}")
print(f"Best fitness: {result.best_fitness:.8f}")
print(f"Best solution: cities={result.best_solution}")
print(f"Best distance: {problem._sol_distance(result.best_solution):.8f}")
print(f"Evaluations used: {result.evaluations_used}")
print(f"Generations: {len(result.history)}")
# Out:
# ========================================
# RESULTS
# ========================================
# Problem: TSProblem
# Best fitness: 24.23221402
# Best solution: cities=[np.int64(2), np.int64(39), np.int64(63), np.int64(46), np.int64(97), np.int64(15), np.int64(78), np.int64(4), np.int64(76), np.int64(26), np.int64(34), np.int64(19), np.int64(48), np.int64(5), np.int64(75), np.int64(71), np.int64(94), np.int64(25), np.int64(93), np.int64(72), np.int64(8), np.int64(68), np.int64(98), np.int64(27), np.int64(11), np.int64(45), np.int64(23), np.int64(36), np.int64(10), np.int64(41), np.int64(59), np.int64(29), np.int64(51), np.int64(18), np.int64(67), np.int64(28), np.int64(64), np.int64(58), np.int64(95), np.int64(9), np.int64(38), np.int64(99), np.int64(21), np.int64(3), np.int64(85), np.int64(0), np.int64(6), np.int64(43), np.int64(73), np.int64(1), np.int64(7), np.int64(12), np.int64(13), np.int64(14), np.int64(16), np.int64(17), np.int64(20), np.int64(22), np.int64(24), np.int64(30), np.int64(31), np.int64(32), np.int64(33), np.int64(35), np.int64(37), np.int64(40), np.int64(42), np.int64(44), np.int64(47), np.int64(49), np.int64(50), np.int64(52), np.int64(53), np.int64(54), np.int64(55), np.int64(56), np.int64(57), np.int64(92), np.int64(61), np.int64(62), np.int64(65), np.int64(66), np.int64(69), np.int64(70), np.int64(74), np.int64(77), np.int64(79), np.int64(80), np.int64(81), np.int64(82), np.int64(83), np.int64(84), np.int64(86), np.int64(87), np.int64(88), np.int64(89), np.int64(90), np.int64(91), np.int64(60), np.int64(96)]
# Best distance: 24.08795322
# Evaluations used: 1000000
# Generations: 20001

# %%
cities_solution = [cities[idx] for idx in result.best_solution]
cities_solution.append(cities_solution[0])

fig, ax = create_figure()
plot_nodes(ax, cities)
plot_path(ax, cities_solution)

# %%
res2 = problem.get_aco_result(
    ant_count=50,
    iterations=20,
    alpha=1.0,  # Importancia de la feromona
    beta=5.0,  # Importancia de la distancia
    rho=0.1,  # Evaporación de la feromona
    q0=0.7,  # Explotación
    elite_count=3,
    stagnation_limit=10,
    random_state=1,
)
# Out:
# Iteración 1/20: Mejor distancia = 7.80, Actual mejor distancia = 7.80, Promedio de población = 7.84
# Iteración 2/20: Mejor distancia = 7.80, Actual mejor distancia = 7.81, Promedio de población = 7.82
# Iteración 3/20: Mejor distancia = 7.70, Actual mejor distancia = 7.70, Promedio de población = 7.72
# Iteración 4/20: Mejor distancia = 7.70, Actual mejor distancia = 7.70, Promedio de población = 7.74
# Iteración 5/20: Mejor distancia = 7.70, Actual mejor distancia = 7.70, Promedio de población = 7.72
# Iteración 6/20: Mejor distancia = 7.70, Actual mejor distancia = 7.70, Promedio de población = 7.75
# Iteración 7/20: Mejor distancia = 7.67, Actual mejor distancia = 7.67, Promedio de población = 7.73
# Iteración 8/20: Mejor distancia = 7.67, Actual mejor distancia = 7.67, Promedio de población = 7.68
# Iteración 9/20: Mejor distancia = 7.67, Actual mejor distancia = 7.67, Promedio de población = 7.72
# Iteración 10/20: Mejor distancia = 7.67, Actual mejor distancia = 7.67, Promedio de población = 7.69
# Iteración 11/20: Mejor distancia = 7.66, Actual mejor distancia = 7.66, Promedio de población = 7.68
# Iteración 12/20: Mejor distancia = 7.65, Actual mejor distancia = 7.65, Promedio de población = 7.67
# Iteración 13/20: Mejor distancia = 7.65, Actual mejor distancia = 7.66, Promedio de población = 7.67
# Iteración 14/20: Mejor distancia = 7.65, Actual mejor distancia = 7.65, Promedio de población = 7.66
# Iteración 15/20: Mejor distancia = 7.65, Actual mejor distancia = 7.65, Promedio de población = 7.66
# Iteración 16/20: Mejor distancia = 7.65, Actual mejor distancia = 7.65, Promedio de población = 7.66
# Iteración 17/20: Mejor distancia = 7.65, Actual mejor distancia = 7.65, Promedio de población = 7.66
# Iteración 18/20: Mejor distancia = 7.65, Actual mejor distancia = 7.65, Promedio de población = 7.66
# Iteración 19/20: Mejor distancia = 7.65, Actual mejor distancia = 7.65, Promedio de población = 7.66
# Iteración 20/20: Mejor distancia = 7.65, Actual mejor distancia = 7.65, Promedio de población = 7.66

# %%
# La mejor solución encontrada hasta ahora fue 7.59 (sin semilla, así que ahora mismo no lo podemos replicar)
fig, ax = create_figure()
plot_nodes(ax, cities)
optimal_path = [cities[idx] for idx in res2.best_solution]
optimal_path.append(optimal_path[0])
plot_path(ax, optimal_path)
print(optimal_path)
# Out:
# [(0.2837581848186974, 0.02576704782244421), (0.2630560480211699, 0.010670642241309536), (0.20196772698059162, 0.046358747430397584), (0.13881496219356027, 0.048489530185603646), (0.06451313705472006, 0.12606114349173192), (0.01801973379815025, 0.12175434785651695), (0.05603526365085032, 0.3149530712641142), (0.005128451667189338, 0.4655718085045638), (0.08674110453583683, 0.4491174987265194), (0.13373527735293878, 0.5336853876899833), (0.0031474687633804566, 0.6974574785