# %%
cd ..
# Out:
# c:\Users\Yago\Desktop\MAADM\3 Computación Evolutiva y Bioinspirada\practica_biocomp

# %%
from genetic.algorithms import GeneticAlgorithmMO
from genetic.configurations import ProblemConfig
from genetic.crossover import BlendCrossover
from genetic.initialization import RandomInitialization
from genetic.mutation import UniformMutation
from genetic.problems import PymooProblem
from genetic.replacement import GenerationalReplacement
from genetic.selection import ParetoSelection

# %%
config = ProblemConfig(max_evaluations=10000, seed=42, output_dir="results/zdt1")

# Problem
name = "zdt1"
problem = PymooProblem(config, name, n_var=30)

# Operators
initialization = RandomInitialization()
selection = ParetoSelection()
crossover = BlendCrossover(alpha=0.5)
mutation = UniformMutation(mutation_rate=0.15, bounds=problem.get_bounds())
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
)

# %%
print("=" * 80)
print("OPTIMIZING ZDT1 FUNCTIONS")
print("=" * 80)
result = ga.run()
# Out:
# ================================================================================
# OPTIMIZING ZDT1 FUNCTIONS
# ================================================================================
# Gen 0: Evals=50/10000, Pareto size=7, Sample objectives=['0.6394', '3.0042']
# Gen 10: Evals=550/10000, Pareto size=10, Sample objectives=['0.3058', '3.4889']
# Gen 20: Evals=1050/10000, Pareto size=19, Sample objectives=['0.6522', '2.4073']
# Gen 30: Evals=1550/10000, Pareto size=22, Sample objectives=['0.3857', '3.6869']
# Gen 40: Evals=2050/10000, Pareto size=18, Sample objectives=['0.0800', '3.9788']
# Gen 50: Evals=2550/10000, Pareto size=20, Sample objectives=['0.8795', '2.1251']
# Gen 60: Evals=3050/10000, Pareto size=21, Sample objectives=['0.3004', '3.6417']
# Gen 70: Evals=3550/10000, Pareto size=22, Sample objectives=['0.2686', '3.3913']
# Gen 80: Evals=4050/10000, Pareto size=20, Sample objectives=['0.3148', '3.2392']
# Gen 90: Evals=4550/10000, Pareto size=21, Sample objectives=['0.8680', '3.3847']
# Gen 100: Evals=5050/10000, Pareto size=21, Sample objectives=['0.1460', '3.5368']
# Gen 110: Evals=5550/10000, Pareto size=20, Sample objectives=['0.6126', '3.4013']
# Gen 120: Evals=6050/10000, Pareto size=20, Sample objectives=['0.3036', '3.9263']
# Gen 130: Evals=6550/10000, Pareto size=21, Sample objectives=['0.4235', '3.4005']
# Gen 140: Evals=7050/10000, Pareto size=21, Sample objectives=['0.3651', '3.2950']
# Gen 150: Evals=7550/10000, Pareto size=19, Sample objectives=['0.5031', '3.0462']
# Gen 160: Evals=8050/10000, Pareto size=17, Sample objectives=['0.3269', '3.3671']
# Gen 170: Evals=8550/10000, Pareto size=18, Sample objectives=['0.7103', '2.9027']
# Gen 180: Evals=9050/10000, Pareto size=20, Sample objectives=['0.2358', '3.5703']
# Gen 190: Evals=9550/10000, Pareto size=21, Sample objectives=['0.1358', '3.2236']

# %%
print("\n" + "=" * 40)
print("RESULTS")
print("=" * 40)
print(f"Problem: {result.problem_name}")
print(f"Evaluations used: {result.evaluations_used}")
print(f"Generations: {len(result.history)}")
print(f"Metrics:")
for metric, value in result.metrics.items():
    print(f"  - {metric}: {value}")
# Out:
# ========================================
# RESULTS
# ========================================
# Problem: PymooProblem
# Evaluations used: 10000
# Generations: 0
# Metrics:
#   - n_pareto_solutions: 23
#   - pareto_spread: 0.3402205479232421
#   - history_length: 201

# %%
front = problem.plot_pareto_front(True)
front.show()
