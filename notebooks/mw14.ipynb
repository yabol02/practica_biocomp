# %%
cd ..
# Out:
# c:\Users\rahar\Desktop\master\BIOCOMP\backup\practica_biocomp

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from genetic.algorithms import GeneticAlgorithmMO
from genetic.configurations import ProblemConfig
from genetic.crossover import BlendCrossover
from genetic.initialization import RandomInitialization
from genetic.mutation import UniformMutation
from genetic.problems import PymooProblem
from genetic.replacement import GenerationalReplacement
from genetic.selection import ParetoSelection

# %% [markdown]
# # First try

# %%
config = ProblemConfig(max_evaluations=10000, seed=42, output_dir="results/zdt1")

# Problem
name = "mw14"
problem = PymooProblem(config, name, n_var=30)

# Operators
initialization = RandomInitialization()
selection = ParetoSelection()
crossover = BlendCrossover(alpha=0.5)
mutation = UniformMutation(mutation_rate=0.15, bounds=problem.get_bounds())
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
)

# %%
print("=" * 80)
print("OPTIMIZING ZDT1 FUNCTIONS")
print("=" * 80)
result = ga.run()
# Out:
# ================================================================================
# OPTIMIZING ZDT1 FUNCTIONS
# ================================================================================
# Gen 0: Evals=50/10000, Pareto size=20, Sample objectives=['0.9591', '0.0375', '65.1665']
# Gen 10: Evals=550/10000, Pareto size=54, Sample objectives=['0.1926', '1.0125', '65.7271']
# Gen 20: Evals=1050/10000, Pareto size=64, Sample objectives=['0.7040', '0.4869', '37.2555']
# Gen 30: Evals=1550/10000, Pareto size=75, Sample objectives=['0.6770', '0.0000', '50.0816']
# Gen 40: Evals=2050/10000, Pareto size=80, Sample objectives=['0.2842', '0.0266', '60.8914']
# Gen 50: Evals=2550/10000, Pareto size=83, Sample objectives=['1.5000', '0.0000', '24.1061']
# Gen 60: Evals=3050/10000, Pareto size=88, Sample objectives=['0.4506', '0.3882', '45.8419']
# Gen 70: Evals=3550/10000, Pareto size=93, Sample objectives=['0.4055', '0.2402', '64.1876']
# Gen 80: Evals=4050/10000, Pareto size=86, Sample objectives=['0.0761', '0.1897', '35.8165']
# Gen 90: Evals=4550/10000, Pareto size=89, Sample objectives=['1.3020', '0.6464', '59.1386']
# Gen 100: Evals=5050/10000, Pareto size=86, Sample objectives=['0.4343', '0.5977', '31.5709']
# Gen 110: Evals=5550/10000, Pareto size=92, Sample objectives=['1.5000', '0.6999', '10.2626']
# Gen 120: Evals=6050/10000, Pareto size=97, Sample objectives=['1.4613', '1.0765', '40.4870']
# Gen 130: Evals=6550/10000, Pareto size=98, Sample objectives=['0.1582', '0.2485', '52.1093']
# Gen 140: Evals=7050/10000, Pareto size=102, Sample objectives=['0.0000', '0.0000', '73.2494']
# Gen 150: Evals=7550/10000, Pareto size=105, Sample objectives=['0.5771', '0.2382', '49.6476']
# Gen 160: Evals=8050/10000, Pareto size=109, Sample objectives=['0.0930', '1.1709', '110.8646']
# Gen 170: Evals=8550/10000, Pareto size=109, Sample objectives=['0.3907', '1.3077', '25.8557']
# Gen 180: Evals=9050/10000, Pareto size=119, Sample objectives=['1.5000', '0.0715', '32.8903']
# Gen 190: Evals=9550/10000, Pareto size=129, Sample objectives=['1.4395', '1.0237', '32.9639']

# %%
print("\n" + "=" * 40)
print("RESULTS")
print("=" * 40)
print(f"Problem: {result.problem_name}")
print(f"Evaluations used: {result.evaluations_used}")
print(f"Generations: {len(result.history)}")
print(f"Metrics:")
for metric, value in result.metrics.items():
    print(f"  - {metric}: {value}")
# Out:
# ========================================
# RESULTS
# ========================================
# Problem: PymooProblem
# Evaluations used: 10000
# Generations: 0
# Metrics:
#   - n_pareto_solutions: 133
#   - pareto_spread: 25.66140777415465
#   - history_length: 201

# %%
front = problem.plot_pareto_front(True)
front.show()

# %% [markdown]
# # Second try

# %%
def print_result(result):
    print("\n" + "=" * 40)
    print("RESULTS")
    print("=" * 40)
    print(f"Problem: {result.problem_name}")
    print(f"Evaluations used: {result.evaluations_used}")
    print(f"Generations: {len(result.history)}")
    print(f"Metrics:")
    for metric, value in result.metrics.items():
        print(f"  - {metric}: {value}")

# %%
config = ProblemConfig(max_evaluations=10000, seed=42, output_dir="results/zdt1")

# Problem
name = "mw14"
problem = PymooProblem(config, name, n_var=30)

# Operators
initialization = RandomInitialization()
selection = ParetoSelection()
crossover = BlendCrossover(alpha=0.5)
mutation = UniformMutation(mutation_rate=0.001, bounds=problem.get_bounds())
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
)

result = ga.run()
print_result(result)
front = problem.plot_pareto_front(True)
front.show()
# Out:
# Gen 0: Evals=50/10000, Pareto size=20, Sample objectives=['0.9591', '0.0375', '65.1665']
# Gen 10: Evals=550/10000, Pareto size=47, Sample objectives=['0.0000', '1.5000', '21.6006']
# Gen 20: Evals=1050/10000, Pareto size=59, Sample objectives=['0.1207', '0.3171', '28.3722']
# Gen 30: Evals=1550/10000, Pareto size=76, Sample objectives=['0.5010', '0.5910', '11.6737']
# Gen 40: Evals=2050/10000, Pareto size=64, Sample objectives=['0.0000', '0.0000', '14.2592']
# Gen 50: Evals=2550/10000, Pareto size=119, Sample objectives=['0.6385', '0.6987', '6.9167']
# Gen 60: Evals=3050/10000, Pareto size=191, Sample objectives=['0.1128', '1.4231', '6.5485']
# Gen 70: Evals=3550/10000, Pareto size=170, Sample objectives=['0.5343', '0.5562', '7.0210']
# Gen 80: Evals=4050/10000, Pareto size=242, Sample objectives=['0.1882', '0.7055', '7.9706']
# Gen 90: Evals=4550/10000, Pareto size=260, Sample objectives=['0.1689', '0.8372', '8.2139']
# Gen 100: Evals=5050/10000, Pareto size=241, Sample objectives=['0.0229', '1.2396', '6.7731']
# Gen 110: Evals=5550/10000, Pareto size=277, Sample objectives=['0.3732', '0.6715', '6.5673']
# Gen 120: Evals=6050/10000, Pareto size=296, Sample objectives=['0.0718', '0.7541', '7.7356']
# Gen 130: Evals=6550/10000, Pareto size=336, Sample objectives=['0.3940', '0.4091', '7.4936']
# Gen 140: Evals=7050/10000, Pareto size=277, Sample objectives=['0.5074', '1.1618', '4.8187']
# Gen 150: Evals=7550/10000, Pareto size=215, Sample objectives=['0.6279', '0.9663', '4.4334']
# Gen 160: Evals=8050/10000, Pareto size=353, Sample objectives=['0.1727', '0.4268', '6.0144']
# Gen 170: Evals=8550/10000, Pareto size=497, Sample objectives=['0.6692', '0.4404', '4.3981']
# Gen 180: Evals=9050/10000, Pareto size=593, Sample objectives=['0.5177', '0.4890', '4.5067']
# Gen 190: Evals=9550/10000, Pareto size=558, Sample objectives=['0.2727', '0.4920', '5.4326']
#
# ========================================
# RESULTS
# ========================================
# Problem: PymooProblem
# Evaluations used: 10000
# Generations: 0
# Metrics:
#   - n_pareto_solutions: 575
#   - pareto_spread: 0.3308999405909612
#   - history_length: 201

# %% [markdown]
# # Third try, trying to get equal results

# %%
config = ProblemConfig(max_evaluations=10000, seed=42, output_dir="results/zdt1")

# Problem
name = "mw14"
problem = PymooProblem(config, name, n_var=30)

# Operators
initialization = RandomInitialization()
selection = ParetoSelection()
crossover = BlendCrossover(alpha=0.5)
mutation = UniformMutation(mutation_rate=0.01, bounds=problem.get_bounds())
replacement = GenerationalReplacement()

# Genetic Algorithm
ga = GeneticAlgorithmMO(
    problem=problem,
    population_size=50,
    initialization=initialization,
    selection=selection,
    crossover=crossover,
    mutation=mutation,
    replacement=replacement,
)

result = ga.run()
print_result(result)
front = problem.plot_pareto_front(True)
front.show()
# Out:
# Gen 0: Evals=50/10000, Pareto size=20, Sample objectives=['0.9591', '0.0375', '65.1665']
# Gen 10: Evals=550/10000, Pareto size=74, Sample objectives=['0.6237', '1.5000', '16.6914']
# Gen 20: Evals=1050/10000, Pareto size=68, Sample objectives=['0.8427', '0.3398', '24.9413']
# Gen 30: Evals=1550/10000, Pareto size=80, Sample objectives=['0.7005', '0.2185', '21.2030']
# Gen 40: Evals=2050/10000, Pareto size=74, Sample objectives=['0.0000', '0.0000', '30.0798']
# Gen 50: Evals=2550/10000, Pareto size=44, Sample objectives=['0.4679', '0.0000', '20.6551']
# Gen 60: Evals=3050/10000, Pareto size=30, Sample objectives=['0.0000', '0.0103', '11.1152']
# Gen 70: Evals=3550/10000, Pareto size=65, Sample objectives=['0.3417', '0.1321', '7.2700']
# Gen 80: Evals=4050/10000, Pareto size=120, Sample objectives=['0.0727', '0.4200', '8.6270']
# Gen 90: Evals=4550/10000, Pareto size=136, Sample objectives=['0.5274', '0.8798', '4.3939']
# Gen 100: Evals=5050/10000, Pareto size=156, Sample objectives=['0.0373', '0.6982', '12.9679']
# Gen 110: Evals=5550/10000, Pareto size=133, Sample objectives=['0.0289', '0.0000', '7.6504']
# Gen 120: Evals=6050/10000, Pareto size=142, Sample objectives=['0.9159', '0.0684', '5.3139']
# Gen 130: Evals=6550/10000, Pareto size=214, Sample objectives=['0.2125', '0.5326', '5.7869']
# Gen 140: Evals=7050/10000, Pareto size=226, Sample objectives=['0.3733', '0.1825', '7.8546']
# Gen 150: Evals=7550/10000, Pareto size=201, Sample objectives=['0.5764', '0.4741', '4.0344']
# Gen 160: Evals=8050/10000, Pareto size=239, Sample objectives=['0.1712', '0.4546', '5.3643']
# Gen 170: Evals=8550/10000, Pareto size=273, Sample objectives=['0.6618', '0.4163', '4.0756']
# Gen 180: Evals=9050/10000, Pareto size=303, Sample objectives=['0.9512', '0.3144', '11.5873']
# Gen 190: Evals=9550/10000, Pareto size=307, Sample objectives=['0.4509', '0.4272', '5.4642']
#
# ========================================
# RESULTS
# ========================================
# Problem: PymooProblem
# Evaluations used: 10000
# Generations: 0
# Metrics:
#   - n_pareto_solutions: 309
#   - pareto_spread: 0.46038607305280554
#   - history_length: 201

# %% [markdown]
# # NSGA-II

# %%
res2 = problem.get_nsga2_result()
front2 = problem.plot_pareto_front(True)
front2.show()
